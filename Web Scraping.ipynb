# %% [markdown]
# # Lab 1 | Web Scraping Single Page

# %%
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://www.popvortex.com/music/charts/top-100-songs.php"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
len(response.content)
# Out:
# 366287

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><title>iTunes Top 100 Songs Chart 2022</title><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="iTunes top 100 songs chart list. The most popular hit music and trending songs of 2022. Chart of today's current iTunes top 100 songs is updated daily." name="description"/><meta content="iTunes Top 100 Songs Chart 2022" property="og:title"><meta content="Chart of the top 100 songs on iTunes. Chart list of the top 100 song downloads of 2022 is updated daily." property="og:description"><meta content="article" property="og:type"><meta content="https://www.popvortex.com/images/logo-facebook.png" property="og:image"/><meta content="PopVortex" property="og:site_name"/><meta content="https://www.popvortex.com/music/charts/top-100-songs.php" property="og:url"/><meta content="100000239962942" property="fb:admins"/><meta content="178831188827052" property="fb:app_id"/><link href="/favicon.png" rel="shortcut icon"/><link href="/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed"><link href="//www.google-analytics.com" rel="dns-prefetch"/><link as="style" href="/css/combined.min.css?version-2022-06-25" rel="preload"/><link href="/css/combined.min.css?version-2022-06-25" rel="stylesheet"><link href="https://www.popvortex.com/music/charts/top-100-songs.php" rel="canonical"><link href="https://www.popvortex.com/amp/music/top-100-songs.php" rel="amphtml"/><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-2993910-6"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'UA-2993910-6');
#   gtag('config', 'G-QRYP06945T');
# </script>
# </link></link></link></meta></meta></meta></head><body><div class="container"><nav aria-label="Main" class="navbar navbar-default navbar-fixed-top"><div class="container"><div class="navbar-header"><button class="navbar-toggle" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button"><span class="sr-only">Toggle navigation</span> <span class="icon-bar"></span><span class="icon-bar"></span><span class="icon-bar"></span></button><a class="navbar-brand" href="/"><img alt="PopVortex - Music, Books, Movies, Televsion" height="80" src="/images/popvortex-logo.png" style="border-width: 0px" width="126"/></a> </div><div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1"><ul class="nav navbar-nav"><li class="dropdown active"><a class="dropdown-toggle" data-toggle="dropdown" href="/music/">Music <b class="caret"></b></a><ul class="dropdown-menu"><li><a href="/music/">Music News and Reviews</a></li><li><a href="/music/charts/">iTunes Music Charts</a></li><li class="divider"></li><li><a href="/music/charts/"><strong>iTunes Top Song Charts</strong></a></li><li><a href="/music/charts/top-100-songs.php">iTunes Top 100 Songs</a></li><li><a href="/music/charts/apple-music-top-songs.php">Apple Top 200 Streams</a></li><li><a href="/music/charts/top-country-songs.php">Top Country Songs</a></li><li><a href="/music/charts/top-pop-songs.php">Top Pop Songs</a></li><li><a href="/music/charts/top-rap-songs.php">Top Rap Songs</a></li><li><a href="/music/charts/top-alternative-songs.php">Top Alternative Songs</a></li> <li class="divider"></li><li><a href="/music/charts/"><strong>iTunes Top Album Charts</strong></a></li><li><a href="/music/charts/top-100-albums.php">iTunes Top 100 Albums</a></li><li><a href="/music/charts/top-country-albums.php">Top Country Albums</a></li><li><a href="/music/charts/top-pop-albums.php">Top Pop Albums</a></li><li><a href="/music/charts/top-rap-albums.php">Top Rap Albums</a></li><li><a href="/music/charts/top-alternative-albums.php">Top Alternative Albums</a></li><li class="divider"></li><li><a href="/charts/international-charts.php">International iTunes Charts</a></li></ul></li><li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="/books/">Books <b class="caret"></b></a><ul class="dropdown-menu"><li><a href="/books/">Book News and Reviews</a></li><li class="divider"></li><li><a href="/books/charts/audiobooks.php"><strong>Audiobook Charts by Genre</strong></a></li><li><a href="/books/charts/top-audio-books.php">Audiobook Bestsellers</a></li><li><a href="/books/charts/fiction-audiobooks.php">Fiction Audiobook Best Sellers</a></li><li><a href="/books/charts/non-fiction-audiobooks.php">Non-Fiction Audiobook Best Sellers</a></li><li><a href="/books/charts/new-audiobooks.php">Top New Audiobooks</a></li><li class="divider"></li><li><a href="/books/charts/ebooks.php"><strong>Ebook Best Seller Charts by Genre</strong></a></li><li><a href="/books/charts/top-ebooks.php">Ebook Best Sellers</a></li><li><a href="/books/charts/top-fiction-ebooks.php">Fiction Ebook Best Sellers</a></li><li><a href="/books/charts/top-non-fiction-ebooks.php">Non-Fiction Ebook Best Sellers</a></li></ul></li><li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="/movies/">Movies <b class="caret"></b></a><ul class="dropdown-menu"><li><a href="/movies/">Movie News, Revies &amp; Box Office Reports</a></li><li class="divider"></li><li><a href="/movies/charts/top-movies.php">Top iTunes Movies</a></li></ul></li><li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="/tv/">Television <b class="caret"></b></a><ul class="dropdown-menu"><li><a href="/tv/">TV News</a></li><li class="divider"></li><li><a href="/tv/charts/top-tv-episodes.php">Top TV Episodes</a></li><li><a href="/tv/charts/top-tv-seasons.php">Top TV Seasons</a></li></ul></li><li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="/apps/charts/top-paid-apps.php">Apps <b class="caret" ...
# <div class="gcse-search"></div></div></div></div></nav><div class="breadcrumbs cf"><ul><li><a href="/">Home</a></li><li><a href="/music/">Music</a></li><li><a href="/music/charts/">Music Charts</a></li> <li><strong><a href="https://www.popvortex.com/music/charts/top-100-songs.php">iTunes Top 100 Songs</a></strong></li></ul></div><div class="flex-row banner-wrapper" id="banner-section"><div class="col-md-12 main-banner"><ins class="adsbygoogle hero-ad" data-ad-client="ca-pub-1860638006024050" data-ad-slot="8782193340" style="display:block"></ins><script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script></div></div><div class="flex-row"><div class="col-xs-12 col-md-8" role="article"><h1>iTunes Top 100 Songs Chart</h1><p>Chart of <strong>iTunes top 100 songs</strong> downloaded at the Apple iTunes music store today. The iTunes top 100 songs chart list countdown includes the hottest and most popular music hits and singles from all musical genres including today's hot <a href="top-pop-songs.php">pop</a>, <a href="top-rap-songs.php">rap</a>, <a href="top-rock-songs.php">rock</a>, and <a href="top-country-songs.php">country</a> songs.</p><p>The chart of the current best selling hot 100 song downloads on iTunes right now is updated daily and is for the top singles in the USA.</p><p>The number one song on iTunes right now is <strong><a href="https://music.apple.com/us/album/about-damn-time/1619161952?i=1619162353&amp;uo=2&amp;partnerId=11&amp;at=10l4UI" rel="nofollow">About Damn Time by Lizzo</a></strong>.</p><p>Chart of the top 100 hot tracks and singles <span>last updated: <time>July, 18 2022</time></span></p><p><strong>Related Charts</strong>: <a href="apple-music-top-songs.php">Apple Music Top Streaming Songs</a>, <a href="itunes-top-400-songs.php">iTunes Top 200 Songs</a>, <a href="top-new-songs.php">Top New Songs  July 2022</a>, <a href="top-100-albums.php">Top 100 Albums</a>, and <a href="top-music-videos.php">Top 40 Music Videos</a>.</p><h2 class="chart-heading">Top 100 Songs 2022</h2><div class="flex-row rev-row"><div class="col-md-12 col-xs-12 col-rev"><div class="chart-ad"><ins class="adsbygoogle chart-music-responsive" data-ad-client="ca-pub-1860638006024050" data-ad-slot="6328254542" data-full-width-responsive="true" style="display:block"></ins><script>(adsbygoogle = window.adsbygoogle || []).push({});</script>
# </div></div></div><div class="chart-wrapper"><div class="feed-item music-chart flex-row" id="chart-position-1"><div class="cover-art col-xs-12 col-sm-4"><p class="chart-position">1</p><img alt="About Damn Time - Lizzo Cover Art" class="cover-image" data-pin-description="About Damn Time - Lizzo" data-pin-media="https://is2-ssl.mzstatic.com/image/thumb/Music122/v4/66/40/9c/66409ca7-50a8-0a2b-f785-2992e9b3fb9b/075679749123.jpg/1200x1200bb.png" data-pin-url="https://www.popvortex.com/music/charts/top-100-songs.php" height="170" loading="lazy" src="https://is2-ssl.mzstatic.com/image/thumb/Music122/v4/66/40/9c/66409ca7-50a8-0a2b-f785-2992e9b3fb9b/075679749123.jpg/170x170bb.png" width="170"/> <audio controls="" controlslist="nodownload" preload="none"><source src="https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview122/v4/81/e6/0a/81e60a84-3e94-7af1-7907-a07f3ae09a24/mzaf_5134479995596811902.plus.aac.p.m4a"/></audio> </div><div class="chart-content col-xs-12 col-sm-8"><p class="title-artist"><cite class="title">About Damn Time</cite><em class="artist">Lizzo</em></p><ul><li><strong>Genre</strong>: <a href="/music/charts/top-pop-songs.php">Pop</a></li><li><strong>Release Date</strong>: April 14, 2022</li></ul><a class="buy-button button" href="https://music.apple.com/us/album/about-damn-time/1619161952?i=1619162353&amp;uo=2&amp;partnerId=11&amp;at=10l4UI&amp;itsct=music_box_link&amp;itscg=30200&amp;ls=1&amp;ct=music-songs&amp;app=music" rel="nofollow noopener">Apple Music / iTunes</a> <a aria-label="Buy About Damn Time - Lizzo on Amazon" class="amazon-buy button" href="https://www.amazon.com/gp/search?ie=UTF8&amp;keywords=About+Damn+Time+Lizzo&amp;tag=popv0f-20&amp;search-alias=digital-music" rel="nofollow noopener" target="_blank">Buy on Amazon</a> <div class="social-share"><a class="facebook-share-button" href="javascript: void(0)" onclick="window.open('https://www.facebook.com/dialog/feed?app_id=178831188827052&amp;display=popup&amp;description=About+Damn+Time+by+Lizzo+is+currently+at+number+1+on+the+iTunes+top+100+songs+chart.&amp;link=https%3A%2F%2Fwww.popvortex.com%2Fmusic%2Fcharts%2Ftop-100-songs.php&amp;redirect_uri=http%3A%2F%2Fwww.popvortex.com%2Fpopup-close.html&amp;picture=https%3A%2F%2Fis2-ssl.mzstatic.com%2Fimage%2Fthumb%2FMusic122%2Fv4%2F66%2F40%2F9c%2F66409ca7-50a8-0a2b-f785-2992e9b3fb9b%2F075679749123.jpg%2F170x170bb.png','sharer','toolbar=0,status=0,width=548,height=325');"><img alt="Share on Facebook" height="20" loading="lazy" src="../../images/facebook-share.png" width="55"/></a> <a class="pinterest-share-button" data-pin-config="none" data-pin-do="buttonPin" href="//pinterest.com/pin/create/button/?url=https%3A%2F%2Fwww.popvortex.com%2Fmusic%2Fcharts%2Ftop-100-songs.php&amp;media=https%3A%2F%2Fis2-ssl.mzstatic.com%2Fimage%2Fthumb%2FMusic122%2Fv4%2F66%2F40%2F9c%2F66409ca7-50a8-0a2b-f785-2992e9b3fb9b%2F075679749123.jpg%2F1200x1200bb.png&amp;description=About Damn Time - Lizzo"><img alt="Pinterest Button" height="20" loading="lazy" src="//assets.pinterest.com/images/pidgets/pin_it_button.png" width="40"/></a> <a class="tweet-button" href="https://twitter.com/intent/tweet?text=About+Damn+Time+by+Lizzo+is+%231+on+iTunes+top+100+songs+chart.&amp;hashtags=iTunes&amp;url=https://www.popvortex.com/music/charts/top-100-songs.php"><span></span>Tweet</a></div></div></div><div class="feed-item music-chart flex-row" id="chart-position-2"><div class="cover-art col-xs-12 col-sm-4"><p class="chart-position">2</p><img alt="Running Up That Hill (A Deal with God) - Kate Bush Cover Art" class="cover-image" data-pin-description="Running Up That Hill (A Deal with God) - Kate Bush" data-pin-media="https://is5-ssl.mzstatic.com/image/thumb/Music114/v4/35/f6/02/35f60270-5280-7bc7-4e26-116d91bf592b/190295511685.jpg/1200x1200bb.png" data-pin-url="https://www.popvortex.com/music/charts/top-100-songs.php" height="170" loading="lazy" src="https://is5-ssl.mzstatic.com/image/thumb/Music114/v4/35/f6/02/35f60270-5280-7bc7-4e26-116d91bf592b/ ...
# </div></div></div><div class="feed-item music-chart flex-row new-release" id="chart-position-4"><div class="cover-art col-xs-12 col-sm-4"><p class="chart-position">4</p><img alt="Names - Tom MacDonald Cover Art" class="cover-image" data-pin-description="Names - Tom MacDonald" data-pin-media="https://is1-ssl.mzstatic.com/image/thumb/Music122/v4/b1/e5/37/b1e537da-eab0-318f-e73b-c8dbbd33569c/859763718048_cover.jpg/1200x1200bb.png" data-pin-url="https://www.popvortex.com/music/charts/top-100-songs.php" height="170" loading="lazy" src="https://is1-ssl.mzstatic.com/image/thumb/Music122/v4/b1/e5/37/b1e537da-eab0-318f-e73b-c8dbbd33569c/859763718048_cover.jpg/170x170bb.png" width="170"/> <audio controls="" controlslist="nodownload" preload="none"><source src="https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview122/v4/d2/04/c2/d204c2e0-f936-839f-978e-ac097c8d3032/mzaf_12361913308310255991.plus.aac.p.m4a"/></audio> </div><div class="chart-content col-xs-12 col-sm-8"><p class="title-artist"><cite class="title">Names</cite><em class="artist">Tom MacDonald</em></p><ul><li class="new-release"><a href="top-new-songs.php"><em>New Release</em></a></li><li><strong>Genre</strong>: <a href="/music/charts/top-rap-songs.php">Hip-Hop / Rap</a></li><li><strong>Release Date</strong>: July 15, 2022</li></ul><a class="buy-button button" href="https://music.apple.com/us/album/names/1633835895?i=1633836016&amp;uo=2&amp;partnerId=11&amp;at=10l4UI&amp;itsct=music_box_link&amp;itscg=30200&amp;ls=1&amp;ct=music-songs&amp;app=music" rel="nofollow noopener">Apple Music / iTunes</a> <a aria-label="Buy Names - Tom MacDonald on Amazon" class="amazon-buy button" href="https://www.amazon.com/gp/search?ie=UTF8&amp;keywords=Names+Tom+MacDonald&amp;tag=popv0f-20&amp;search-alias=digital-music" rel="nofollow noopener" target="_blank">Buy on Amazon</a> <div class="social-share"><a class="facebook-share-button" href="javascript: void(0)" onclick="window.open('https://www.facebook.com/dialog/feed?app_id=178831188827052&amp;display=popup&amp;description=Names+by+Tom+MacDonald+is+currently+at+number+4+on+the+iTunes+top+100+songs+chart.&amp;link=https%3A%2F%2Fwww.popvortex.com%2Fmusic%2Fcharts%2Ftop-100-songs.php&amp;redirect_uri=http%3A%2F%2Fwww.popvortex.com%2Fpopup-close.html&amp;picture=https%3A%2F%2Fis1-ssl.mzstatic.com%2Fimage%2Fthumb%2FMusic122%2Fv4%2Fb1%2Fe5%2F37%2Fb1e537da-eab0-318f-e73b-c8dbbd33569c%2F859763718048_cover.jpg%2F170x170bb.png','sharer','toolbar=0,status=0,width=548,height=325');"><img alt="Share on Facebook" height="20" loading="lazy" src="../../images/facebook-share.png" width="55"/></a> <a class="pinterest-share-button" data-pin-config="none" data-pin-do="buttonPin" href="//pinterest.com/pin/create/button/?url=https%3A%2F%2Fwww.popvortex.com%2Fmusic%2Fcharts%2Ftop-100-songs.php&amp;media=https%3A%2F%2Fis1-ssl.mzstatic.com%2Fimage%2Fthumb%2FMusic122%2Fv4%2Fb1%2Fe5%2F37%2Fb1e537da-eab0-318f-e73b-c8dbbd33569c%2F859763718048_cover.jpg%2F1200x1200bb.png&amp;description=Names - Tom MacDonald"><img alt="Pinterest Button" height="20" loading="lazy" src="//assets.pinterest.com/images/pidgets/pin_it_button.png" width="40"/></a> <a class="tweet-button" href="https://twitter.com/intent/tweet?text=Names+by+Tom+MacDonald+is+%234+on+iTunes+top+100+songs+chart.&amp;hashtags=iTunes&amp;url=https://www.popvortex.com/music/charts/top-100-songs.php"><span></span>Tweet</a></div></div></div><div class="feed-item music-chart flex-row" id="chart-position-5"><div class="cover-art col-xs-12 col-sm-4"><p class="chart-position">5</p><img alt="BREAK MY SOUL - Beyoncé Cover Art" class="cover-image" data-pin-description="BREAK MY SOUL - Beyoncé" data-pin-media="https://is2-ssl.mzstatic.com/image/thumb/Music112/v4/05/05/f3/0505f338-9873-feb4-af7f-27a470405e5f/196589246974.jpg/1200x1200bb.png" data-pin-url="https://www.popvortex.com/music/charts/top-100-songs.php" height="170" loading="lazy" src="https://is2-ssl.mzstatic.com/image/thumb/Music112/v4/05/05/f3/0505f338-9873-feb ...
# </div></div></div><div class="feed-item music-chart flex-row" id="chart-position-9"><div class="cover-art col-xs-12 col-sm-4"><p class="chart-position">9</p><img alt="Unstoppable - Sia Cover Art" class="cover-image" data-pin-description="Unstoppable - Sia" data-pin-media="https://is3-ssl.mzstatic.com/image/thumb/Music115/v4/bc/13/27/bc13275c-8b26-802d-771b-d15ae00fb530/mzm.hvpwjsvi.jpg/1200x1200bb.png" data-pin-url="https://www.popvortex.com/music/charts/top-100-songs.php" height="170" loading="lazy" src="https://is3-ssl.mzstatic.com/image/thumb/Music115/v4/bc/13/27/bc13275c-8b26-802d-771b-d15ae00fb530/mzm.hvpwjsvi.jpg/170x170bb.png" width="170"/> <audio controls="" controlslist="nodownload" preload="none"><source src="https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview112/v4/97/85/be/9785be71-997e-d87a-6440-be2bc02b184a/mzaf_1990642628733458305.plus.aac.p.m4a"/></audio> </div><div class="chart-content col-xs-12 col-sm-8"><p class="title-artist"><cite class="title">Unstoppable</cite><em class="artist">Sia</em></p><ul><li><strong>Genre</strong>: <a href="/music/charts/top-pop-songs.php">Pop</a></li><li><strong>Release Date</strong>: January 29, 2016</li></ul><a class="buy-button button" href="https://music.apple.com/us/album/unstoppable/1055074478?i=1055074639&amp;uo=2&amp;partnerId=11&amp;at=10l4UI&amp;itsct=music_box_link&amp;itscg=30200&amp;ls=1&amp;ct=music-songs&amp;app=music" rel="nofollow noopener">Apple Music / iTunes</a> <a aria-label="Buy Unstoppable - Sia on Amazon" class="amazon-buy button" href="https://www.amazon.com/gp/search?ie=UTF8&amp;keywords=Unstoppable+Sia&amp;tag=popv0f-20&amp;search-alias=digital-music" rel="nofollow noopener" target="_blank">Buy on Amazon</a> <div class="social-share"><a class="facebook-share-button" href="javascript: void(0)" onclick="window.open('https://www.facebook.com/dialog/feed?app_id=178831188827052&amp;display=popup&amp;description=Unstoppable+by+Sia+is+currently+at+number+9+on+the+iTunes+top+100+songs+chart.&amp;link=https%3A%2F%2Fwww.popvortex.com%2Fmusic%2Fcharts%2Ftop-100-songs.php&amp;redirect_uri=http%3A%2F%2Fwww.popvortex.com%2Fpopup-close.html&amp;picture=https%3A%2F%2Fis3-ssl.mzstatic.com%2Fimage%2Fthumb%2FMusic115%2Fv4%2Fbc%2F13%2F27%2Fbc13275c-8b26-802d-771b-d15ae00fb530%2Fmzm.hvpwjsvi.jpg%2F170x170bb.png','sharer','toolbar=0,status=0,width=548,height=325');"><img alt="Share on Facebook" height="20" loading="lazy" src="../../images/facebook-share.png" width="55"/></a> <a class="pinterest-share-button" data-pin-config="none" data-pin-do="buttonPin" href="//pinterest.com/pin/create/button/?url=https%3A%2F%2Fwww.popvortex.com%2Fmusic%2Fcharts%2Ftop-100-songs.php&amp;media=https%3A%2F%2Fis3-ssl.mzstatic.com%2Fimage%2Fthumb%2FMusic115%2Fv4%2Fbc%2F13%2F27%2Fbc13275c-8b26-802d-771b-d15ae00fb530%2Fmzm.hvpwjsvi.jpg%2F1200x1200bb.png&amp;description=Unstoppable - Sia"><img alt="Pinterest Button" height="20" loading="lazy" src="//assets.pinterest.com/images/pidgets/pin_it_button.png" width="40"/></a> <a class="tweet-button" href="https://twitter.com/intent/tweet?text=Unstoppable+by+Sia+is+%239+on+iTunes+top+100+songs+chart.&amp;hashtags=iTunes&amp;url=https://www.popvortex.com/music/charts/top-100-songs.php"><span></span>Tweet</a></div></div></div><div class="feed-item music-chart flex-row" id="chart-position-10"><div class="cover-art col-xs-12 col-sm-4"><p class="chart-position">10</p><img alt="About Damn Time - Lizzo Cover Art" class="cover-image" data-pin-description="About Damn Time - Lizzo" data-pin-media="https://is3-ssl.mzstatic.com/image/thumb/Music116/v4/84/94/03/849403d7-0261-391e-ff14-0b801d50ab27/075679747563.jpg/1200x1200bb.png" data-pin-url="https://www.popvortex.com/music/charts/top-100-songs.php" height="170" loading="lazy" src="https://is3-ssl.mzstatic.com/image/thumb/Music116/v4/84/94/03/849403d7-0261-391e-ff14-0b801d50ab27/075679747563.jpg/170x170bb.png" width="170"/> <audio controls="" controlslist="nodownload" preload="none"><source src="https://au ...
# </div></div></div><div class="feed-item music-chart flex-row" id="chart-position-13"><div class="cover-art col-xs-12 col-sm-4"><p class="chart-position">13</p><img alt="Wasted On You - Morgan Wallen Cover Art" class="cover-image" data-pin-description="Wasted On You - Morgan Wallen" data-pin-media="https://is4-ssl.mzstatic.com/image/thumb/Music115/v4/10/a2/39/10a239bc-0f25-69d2-52df-b1fe755dcf19/20UM1IM03632.rgb.jpg/1200x1200bb.png" data-pin-url="https://www.popvortex.com/music/charts/top-100-songs.php" height="170" loading="lazy" src="https://is4-ssl.mzstatic.com/image/thumb/Music115/v4/10/a2/39/10a239bc-0f25-69d2-52df-b1fe755dcf19/20UM1IM03632.rgb.jpg/170x170bb.png" width="170"/> <audio controls="" controlslist="nodownload" preload="none"><source src="https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview112/v4/f7/22/a8/f722a847-2dd7-cd26-eb3a-b0878e9873ea/mzaf_11639295220665330486.plus.aac.p.m4a"/></audio> </div><div class="chart-content col-xs-12 col-sm-8"><p class="title-artist"><cite class="title">Wasted On You</cite><em class="artist">Morgan Wallen</em></p><ul><li><strong>Genre</strong>: <a href="/music/charts/top-country-songs.php">Country</a></li><li><strong>Release Date</strong>: January 8, 2021</li></ul><a class="buy-button button" href="https://music.apple.com/us/album/wasted-on-you/1540314609?i=1540314624&amp;uo=2&amp;partnerId=11&amp;at=10l4UI&amp;itsct=music_box_link&amp;itscg=30200&amp;ls=1&amp;ct=music-songs&amp;app=music" rel="nofollow noopener">Apple Music / iTunes</a> <a aria-label="Buy Wasted On You - Morgan Wallen on Amazon" class="amazon-buy button" href="https://www.amazon.com/gp/search?ie=UTF8&amp;keywords=Wasted+On+You+Morgan+Wallen&amp;tag=popv0f-20&amp;search-alias=digital-music" rel="nofollow noopener" target="_blank">Buy on Amazon</a> <div class="social-share"><a class="facebook-share-button" href="javascript: void(0)" onclick="window.open('https://www.facebook.com/dialog/feed?app_id=178831188827052&amp;display=popup&amp;description=Wasted+On+You+by+Morgan+Wallen+is+currently+at+number+13+on+the+iTunes+top+100+songs+chart.&amp;link=https%3A%2F%2Fwww.popvortex.com%2Fmusic%2Fcharts%2Ftop-100-songs.php&amp;redirect_uri=http%3A%2F%2Fwww.popvortex.com%2Fpopup-close.html&amp;picture=https%3A%2F%2Fis4-ssl.mzstatic.com%2Fimage%2Fthumb%2FMusic115%2Fv4%2F10%2Fa2%2F39%2F10a239bc-0f25-69d2-52df-b1fe755dcf19%2F20UM1IM03632.rgb.jpg%2F170x170bb.png','sharer','toolbar=0,status=0,width=548,height=325');"><img alt="Share on Facebook" height="20" loading="lazy" src="../../images/facebook-share.png" width="55"/></a> <a class="pinterest-share-button" data-pin-config="none" data-pin-do="buttonPin" href="//pinterest.com/pin/create/button/?url=https%3A%2F%2Fwww.popvortex.com%2Fmusic%2Fcharts%2Ftop-100-songs.php&amp;media=https%3A%2F%2Fis4-ssl.mzstatic.com%2Fimage%2Fthumb%2FMusic115%2Fv4%2F10%2Fa2%2F39%2F10a239bc-0f25-69d2-52df-b1fe755dcf19%2F20UM1IM03632.rgb.jpg%2F1200x1200bb.png&amp;description=Wasted On You - Morgan Wallen"><img alt="Pinterest Button" height="20" loading="lazy" src="//assets.pinterest.com/images/pidgets/pin_it_button.png" width="40"/></a> <a class="tweet-button" href="https://twitter.com/intent/tweet?text=Wasted+On+You+by+Morgan+Wallen+is+%2313+on+iTunes+top+100+songs+chart.&amp;hashtags=iTunes&amp;url=https://www.popvortex.com/music/charts/top-100-songs.php"><span></span>Tweet</a></div></div></div><div class="feed-item music-chart flex-row" id="chart-position-14"><div class="cover-art col-xs-12 col-sm-4"><p class="chart-position">14</p><img alt="Rock and A Hard Place - Bailey Zimmerman Cover Art" class="cover-image" data-pin-description="Rock and A Hard Place - Bailey Zimmerman" data-pin-media="https://is3-ssl.mzstatic.com/image/thumb/Music112/v4/98/71/14/987114a8-8023-9bbc-41e2-b053ac024bd7/054391889478.jpg/1200x1200bb.png" data-pin-url="https://www.popvortex.com/music/charts/top-100-songs.php" height="170" loading="lazy" src="https://is3-ssl.mzstatic.com/image/thumb/Music112/v4/98/71/14/987114 ...
# </div></div></div><div class="feed-item music-chart flex-row new-release" id="chart-position-17"><div class="cover-art col-xs-12 col-sm-4"><p class="chart-position">17</p><img alt="Arson - j-hope Cover Art" class="cover-image" data-pin-description="Arson - j-hope" data-pin-media="https://is2-ssl.mzstatic.com/image/thumb/Music112/v4/0e/44/fd/0e44fd82-6ae7-3083-b3a4-c25bd50a527f/196922105265_Cover.jpg/1200x1200bb.png" data-pin-url="https://www.popvortex.com/music/charts/top-100-songs.php" height="170" loading="lazy" src="https://is2-ssl.mzstatic.com/image/thumb/Music112/v4/0e/44/fd/0e44fd82-6ae7-3083-b3a4-c25bd50a527f/196922105265_Cover.jpg/170x170bb.png" width="170"/> <audio controls="" controlslist="nodownload" preload="none"><source src="https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview122/v4/bb/a9/a4/bba9a448-32e0-55f0-0284-0a5ebeb1c13f/mzaf_17327677762115611900.plus.aac.p.m4a"/></audio> </div><div class="chart-content col-xs-12 col-sm-8"><p class="title-artist"><cite class="title">Arson</cite><em class="artist">j-hope</em></p><ul><li class="new-release"><a href="top-new-songs.php"><em>New Release</em></a></li><li><strong>Genre</strong>: <a href="/music/charts/top-kpop-songs.php">K-Pop</a></li><li><strong>Release Date</strong>: July 15, 2022</li></ul><a class="buy-button button" href="https://music.apple.com/us/album/arson/1633259922?i=1633261159&amp;uo=2&amp;partnerId=11&amp;at=10l4UI&amp;itsct=music_box_link&amp;itscg=30200&amp;ls=1&amp;ct=music-songs&amp;app=music" rel="nofollow noopener">Apple Music / iTunes</a> <a aria-label="Buy Arson - j-hope on Amazon" class="amazon-buy button" href="https://www.amazon.com/gp/search?ie=UTF8&amp;keywords=Arson+j-hope&amp;tag=popv0f-20&amp;search-alias=digital-music" rel="nofollow noopener" target="_blank">Buy on Amazon</a> <div class="social-share"><a class="facebook-share-button" href="javascript: void(0)" onclick="window.open('https://www.facebook.com/dialog/feed?app_id=178831188827052&amp;display=popup&amp;description=Arson+by+j-hope+is+currently+at+number+17+on+the+iTunes+top+100+songs+chart.&amp;link=https%3A%2F%2Fwww.popvortex.com%2Fmusic%2Fcharts%2Ftop-100-songs.php&amp;redirect_uri=http%3A%2F%2Fwww.popvortex.com%2Fpopup-close.html&amp;picture=https%3A%2F%2Fis2-ssl.mzstatic.com%2Fimage%2Fthumb%2FMusic112%2Fv4%2F0e%2F44%2Ffd%2F0e44fd82-6ae7-3083-b3a4-c25bd50a527f%2F196922105265_Cover.jpg%2F170x170bb.png','sharer','toolbar=0,status=0,width=548,height=325');"><img alt="Share on Facebook" height="20" loading="lazy" src="../../images/facebook-share.png" width="55"/></a> <a class="pinterest-share-button" data-pin-config="none" data-pin-do="buttonPin" href="//pinterest.com/pin/create/button/?url=https%3A%2F%2Fwww.popvortex.com%2Fmusic%2Fcharts%2Ftop-100-songs.php&amp;media=https%3A%2F%2Fis2-ssl.mzstatic.com%2Fimage%2Fthumb%2FMusic112%2Fv4%2F0e%2F44%2Ffd%2F0e44fd82-6ae7-3083-b3a4-c25bd50a527f%2F196922105265_Cover.jpg%2F1200x1200bb.png&amp;description=Arson - j-hope"><img alt="Pinterest Button" height="20" loading="lazy" src="//assets.pinterest.com/images/pidgets/pin_it_button.png" width="40"/></a> <a class="tweet-button" href="https://twitter.com/intent/tweet?text=Arson+by+j-hope+is+%2317+on+iTunes+top+100+songs+chart.&amp;hashtags=iTunes&amp;url=https://www.popvortex.com/music/charts/top-100-songs.php"><span></span>Tweet</a></div></div></div><div class="feed-item music-chart flex-row" id="chart-position-18"><div class="cover-art col-xs-12 col-sm-4"><p class="chart-position">18</p><img alt="Party In the U.S.A. - Miley Cyrus Cover Art" class="cover-image" data-pin-description="Party In the U.S.A. - Miley Cyrus" data-pin-media="https://is3-ssl.mzstatic.com/image/thumb/Music125/v4/44/26/cc/4426cc53-3242-a46b-facf-c1b5716e4812/00050087152055.rgb.jpg/1200x1200bb.png" data-pin-url="https://www.popvortex.com/music/charts/top-100-songs.php" height="170" loading="lazy" src="https://is3-ssl.mzstatic.com/image/thumb/Music125/v4/44/26/cc/4426cc53-3242-a46b-facf-c1b5716e4812/00050087152 ...
# </div></div></div><div class="feed-item music-chart flex-row" id="chart-position-21"><div class="cover-art col-xs-12 col-sm-4"><p class="chart-position">21</p><img alt="Left and Right - Charlie Puth &amp;amp; Jung Kook Cover Art" class="cover-image" data-pin-description="Left and Right - Charlie Puth &amp; Jung Kook" data-pin-media="https://is3-ssl.mzstatic.com/image/thumb/Music122/v4/8e/89/2e/8e892ef1-7ce6-ca67-a07e-5417194fde4b/075679739155.jpg/1200x1200bb.png" data-pin-url="https://www.popvortex.com/music/charts/top-100-songs.php" height="170" loading="lazy" src="https://is3-ssl.mzstatic.com/image/thumb/Music122/v4/8e/89/2e/8e892ef1-7ce6-ca67-a07e-5417194fde4b/075679739155.jpg/170x170bb.png" width="170"/> <audio controls="" controlslist="nodownload" preload="none"><source src="https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview112/v4/d7/fe/a2/d7fea28a-834e-0246-eb0f-6c68fc397b1c/mzaf_16589178264382104181.plus.aac.p.m4a"/></audio> </div><div class="chart-content col-xs-12 col-sm-8"><p class="title-artist"><cite class="title">Left and Right</cite><em class="artist">Charlie Puth &amp; Jung Kook</em></p><ul><li><strong>Genre</strong>: <a href="/music/charts/top-pop-songs.php">Pop</a></li><li><strong>Release Date</strong>: June 24, 2022</li></ul><a class="buy-button button" href="https://music.apple.com/us/album/left-and-right/1630451412?i=1630451413&amp;uo=2&amp;partnerId=11&amp;at=10l4UI&amp;itsct=music_box_link&amp;itscg=30200&amp;ls=1&amp;ct=music-songs&amp;app=music" rel="nofollow noopener">Apple Music / iTunes</a> <a aria-label="Buy Left and Right - Charlie Puth &amp;amp; Jung Kook on Amazon" class="amazon-buy button" href="https://www.amazon.com/gp/search?ie=UTF8&amp;keywords=Left+and+Right+Charlie+Puth+%26+Jung+Kook&amp;tag=popv0f-20&amp;search-alias=digital-music" rel="nofollow noopener" target="_blank">Buy on Amazon</a> <div class="social-share"><a class="facebook-share-button" href="javascript: void(0)" onclick="window.open('https://www.facebook.com/dialog/feed?app_id=178831188827052&amp;display=popup&amp;description=Left+and+Right+by+Charlie+Puth+%26+Jung+Kook+is+currently+at+number+21+on+the+iTunes+top+100+songs+chart.&amp;link=https%3A%2F%2Fwww.popvortex.com%2Fmusic%2Fcharts%2Ftop-100-songs.php&amp;redirect_uri=http%3A%2F%2Fwww.popvortex.com%2Fpopup-close.html&amp;picture=https%3A%2F%2Fis3-ssl.mzstatic.com%2Fimage%2Fthumb%2FMusic122%2Fv4%2F8e%2F89%2F2e%2F8e892ef1-7ce6-ca67-a07e-5417194fde4b%2F075679739155.jpg%2F170x170bb.png','sharer','toolbar=0,status=0,width=548,height=325');"><img alt="Share on Facebook" height="20" loading="lazy" src="../../images/facebook-share.png" width="55"/></a> <a class="pinterest-share-button" data-pin-config="none" data-pin-do="buttonPin" href="//pinterest.com/pin/create/button/?url=https%3A%2F%2Fwww.popvortex.com%2Fmusic%2Fcharts%2Ftop-100-songs.php&amp;media=https%3A%2F%2Fis3-ssl.mzstatic.com%2Fimage%2Fthumb%2FMusic122%2Fv4%2F8e%2F89%2F2e%2F8e892ef1-7ce6-ca67-a07e-5417194fde4b%2F075679739155.jpg%2F1200x1200bb.png&amp;description=Left and Right - Charlie Puth &amp; Jung Kook"><img alt="Pinterest Button" height="20" loading="lazy" src="//assets.pinterest.com/images/pidgets/pin_it_button.png" width="40"/></a> <a class="tweet-button" href="https://twitter.com/intent/tweet?text=Left+and+Right+by+Charlie+Puth+%26+Jung+Kook+is+%2321+on+iTunes+top+100+songs+chart.&amp;hashtags=iTunes&amp;url=https://www.popvortex.com/music/charts/top-100-songs.php"><span></span>Tweet</a></div></div></div><div class="feed-item music-chart flex-row" id="chart-position-22"><div class="cover-art col-xs-12 col-sm-4"><p class="chart-position">22</p><img alt="Sunroof - Nicky Youre &amp;amp; Dazy Cover Art" class="cover-image" data-pin-description="Sunroof - Nicky Youre &amp; Dazy" data-pin-media="https://is1-ssl.mzstatic.com/image/thumb/Music112/v4/c8/3f/14/c83f14cc-ec3d-ad8e-dfd3-1c7602cc063f/196589131317.jpg/1200x1200bb.png" data-pin-url="https://www.popvortex.com/music/charts/top-100-songs.php" height=" ...
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div></div></div></div><div aria-label="Music Charts" class="col-xs-12 col-md-4 sidenav" role="navigation"><h2><a href="/music/">Music</a></h2><ul><li><a href="/music/">Music News and Reviews</a></li></ul><h2><a href="/music/charts/">iTunes Music Charts (USA)</a></h2><h3>Most Popular Music Charts</h3><ul><li><a href="/music/charts/top-100-songs.php">iTunes Top 100 Songs</a></li><li><a href="/music/charts/apple-music-top-songs.php">Apple Music Top Streaming Songs</a></li><li><a href="/music/charts/top-country-songs.php">Top 100 Country Songs</a></li><li><a href="/music/charts/top-100-albums.php">Top 100 Albums</a></li><li><a href="/music/charts/top-rap-songs.php">Top 100 Rap &amp; Hip Hop Songs</a></li><li><a href="/music/charts/top-pop-songs.php">Top 100 Pop Songs</a></li> </ul><div class="sidebar-revenue"><ins class="adsbygoogle sidenav-ad google-600" data-ad-client="ca-pub-1860638006024050" data-ad-format="auto" data-ad-slot="9490530540" data-full-width-responsive="true" style="display:block"></ins><script>
# 	(adsbygoogle = window.adsbygoogle || []).push({});
# 	</script>
# </div><h3>Top New Music - July 2022</h3><ul><li><a href="/music/charts/top-new-songs.php">Top New Songs</a></li><li><a href="/music/charts/top-new-albums.php">Top New Albums</a></li><li><a href="/music/charts/new-alternative-songs.php">New Alternative Songs</a></li><li><a href="/music/charts/new-country-songs.php">New Country Songs</a></li><li><a href="/music/charts/new-pop-songs.php">New Pop Songs</a></li><li><a href="/music/charts/new-rap-songs.php">New Rap Songs</a></li></ul><h3>iTunes Top 100 Singles Charts</h3><ul><li><a href="/music/charts/top-100-songs.php" title="iTunes Top 100 Songs">Top 100 Songs</a></li><li><a href="/music/charts/apple-music-top-songs.php">Apple Music Top Streaming Songs</a></li><li><a href="/music/charts/itunes-top-400-songs.php">iTunes Top 200 Songs</a></li><li><a href="/music/charts/top-alternative-songs.php">Alternative Songs</a></li><li><a href="/music/charts/top-bluegrass-songs.php">Bluegrass Songs</a></li><li><a href="/music/charts/top-blues-songs.php">Blues Songs</a></li><li><a href="/music/charts/top-christian-gospel-songs.php">Christian &amp; Gospel Songs</a></li><li><a href="/music/charts/top-country-songs.php">Country Songs</a></li><li><a href="/music/charts/top-dance-songs.php">Dance Songs</a></li><li><a href="/music/charts/top-electronic-songs.php">Electronic Songs</a></li><li><a href="/music/charts/top-heavy-metal-songs.php">Heavy Metal Songs</a></li><li><a href="/music/charts/top-indie-songs.php">Indie Rock Songs</a></li><li><a href="/music/charts/top-jazz-songs.php">Jazz Songs</a></li><li><a href="/music/charts/top-kpop-songs.php">K-Pop Songs</a></li><li><a href="/music/charts/top-kids-songs.php">Kids Songs</a></li><li><a href="/music/charts/top-latin-songs.php">Latin Songs</a></li><li><a href="/music/charts/top-pop-songs.php">Pop Songs</a></li><li><a href="/music/charts/top-soul-songs.php">R&amp;B Songs / Soul</a></li><li><a href="/music/charts/top-rap-songs.php">Rap &amp; Hip Hop Songs</a></li><li><a href="/music/charts/top-reggae-songs.php">Reggae Songs</a></li><li><a href="/music/charts/top-reggaeton-songs.php">Reggaeton Songs</a></li><li><a href="/music/charts/top-rock-songs.php">Rock Songs</a></li><li><a href="/music/charts/top-soundtrack-songs.php">Soundtrack Songs</a></li></ul><div class="sidebar-revenue"><a href="https://music.apple.com/subscribe?itsct=music_box_badge&amp;ct=apple-music&amp;itscg=30200&amp;at=10l4UI&amp;app=music&amp;ls=1" rel="nofollow noopener" style="display: inline-block; overflow: hidden; border-radius: 0px; width: 300px; height: 250px;"><img alt="Try Apple Music" loading="lazy" src="https://tools.applemediaservices.com/api/badges/apple-music-banner/iphone-gradient-single-title-v1/en-us?size=300x250&amp;h=2ac057b0409a4f89395a1521c331d265" style="border-radius: 0px; width: 300px; height: 250px;" title=""/></a> </div><h3>iTunes Top 100 Album Charts</h3><ul><li><a href="/music/charts/top-100-albums.php">iTunes Top 100 Albums</a></li><li><a href="/music/charts/itunes-top-400-albums.php">iTunes Top 200 Albums</a></li><li><a href="/music/charts/top-alternative-albums.php">Alternative Albums</a></li><li><a href="/music/charts/top-blues-albums.php">Blues Albums</a></li><li><a href="/music/charts/top-christian-gospel-albums.php">Christian &amp; Gospel Albums</a></li><li><a href="/music/charts/top-classical-albums.php">Classical Albums</a></li><li><a href="/music/charts/comedy-albums.php">Comedy Albums</a></li><li><a href="/music/charts/top-country-albums.php">Country Albums</a></li><li><a href="/music/charts/top-dance-albums.php">Dance Albums</a></li><li><a href="/music/charts/top-electronic-albums.php">Electronic Albums</a></li><li><a href="/music/charts/top-heavy-metal-albums.php">Heavy Metal Albums</a></li><li><a href="/music/charts/top-indie-albums.php">Indie Rock Albums</a></li><li><a href="/music/charts/top-jazz-albums.php">Jazz Albums</a></li><li><a href="/music/charts/top-kpop-albums.php">K-Pop Albums</a></li><li><a href="/music/charts/top-kids-albums.p ...
# 		     (adsbygoogle = window.adsbygoogle || []).push({});
# 		</script>
# </div></div></div></div><hr/></div><div id="footer"><div class="container"><div class="col-md-6 footer-links"><p class="copyright">© Copyright 2010 - 2022 popvortex.com | <a href="/info/contact.php">Contact</a> | <a href="/info/privacy-policy.php">Privacy Policy</a> | iTunes® is a trademark of Apple Inc.</p></div><div class="col-md-6 footer-social"><a data-pin-do="buttonFollow" href="https://www.pinterest.com/popvortex/">Pinterest</a> <a href="https://www.facebook.com/PopVortex"><img alt="Facebook" height="30" src="/images/facebook-icon.png" width="30"/></a> </div></div></div><script async="" crossorigin="anonymous" src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js"></script>
# <script src="/js/jquery.tablesorter.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	$(document).ready(function()
#     {
#         $("#chart-table").tablesorter({sortList: [[0,0]]});
#     }
#     );
# </script>
# <script src="/js/bootstrap.min.js"></script>
# <div id="amzn-assoc-ad-fb723bd8-a1f5-4679-97b5-37609726746c"></div><script async="" crossorigin="anonymous" src="//z-na.amazon-adsystem.com/widgets/onejs?MarketPlace=US&amp;adInstanceId=fb723bd8-a1f5-4679-97b5-37609726746c"></script>
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1860638006024050"></script></body></html>

# %%
soup.select("p.title-artist")
# Out:
# [<p class="title-artist"><cite class="title">About Damn Time</cite><em class="artist">Lizzo</em></p>,
#  <p class="title-artist"><cite class="title">Running Up That Hill (A Deal with God)</cite><em class="artist">Kate Bush</em></p>,
#  <p class="title-artist"><cite class="title">Y'all Life</cite><em class="artist">Walker Hayes</em></p>,
#  <p class="title-artist"><cite class="title">Names</cite><em class="artist">Tom MacDonald</em></p>,
#  <p class="title-artist"><cite class="title">BREAK MY SOUL</cite><em class="artist">Beyoncé</em></p>,
#  <p class="title-artist"><cite class="title">As It Was</cite><em class="artist">Harry Styles</em></p>,
#  <p class="title-artist"><cite class="title">The Kind of Love We Make</cite><em class="artist">Luke Combs</em></p>,
#  <p class="title-artist"><cite class="title">She Had Me At Heads Carolina</cite><em class="artist">Cole Swindell</em></p>,
#  <p class="title-artist"><cite class="title">Unstoppable</cite><em class="artist">Sia</em></p>,
#  <p class="title-artist"><cite class="title">About Damn Time</cite><em class="artist">Lizzo</em></p>,
#  <p class="title-artist"><cite class="title">Quietly Yours</cite><em class="artist">Birdy</em></p>,
#  <p class="title-artist"><cite class="title">I Ain't Worried</cite><em class="artist">OneRepublic</em></p>,
#  <p class="title-artist"><cite class="title">Wasted On You</cite><em class="artist">Morgan Wallen</em></p>,
#  <p class="title-artist"><cite class="title">Rock and A Hard Place</cite><em class="artist">Bailey Zimmerman</em></p>,
#  <p class="title-artist"><cite class="title">Irrelevant</cite><em class="artist">P!nk</em></p>,
#  <p class="title-artist"><cite class="title">Good as Hell</cite><em class="artist">Lizzo</em></p>,
#  <p class="title-artist"><cite class="title">Arson</cite><em class="artist">j-hope</em></p>,
#  <p class="title-artist"><cite class="title">Party In the U.S.A.</cite><em class="artist">Miley Cyrus</em></p>,
#  <p class="title-artist"><cite class="title">Master of Puppets</cite><em class="artist">Metallica</em></p>,
#  <p class="title-artist"><cite class="title">Like I Love Country Music</cite><em class="artist">Kane Brown</em></p>,
#  <p class="title-artist"><cite class="title">Left and Right</cite><em class="artist">Charlie Puth &amp; Jung Kook</em></p>,
#  <p class="title-artist"><cite class="title">Sunroof</cite><em class="artist">Nicky Youre &amp; Dazy</em></p>,
#  <p class="title-artist"><cite class="title">You Proof</cite><em class="artist">Morgan Wallen</em></p>,
#  <p class="title-artist"><cite class="title">Hold My Hand</cite><em class="artist">Lady Gaga</em></p>,
#  <p class="title-artist"><cite class="title">Stay With Me</cite><em class="artist">Calvin Harris, Justin Timberlake, Halsey &amp; Pharrell Williams</em></p>,
#  <p class="title-artist"><cite class="title">AA</cite><em class="artist">Walker Hayes</em></p>,
#  <p class="title-artist"><cite class="title">First Class</cite><em class="artist">Jack Harlow</em></p>,
#  <p class="title-artist"><cite class="title">Hey You</cite><em class="artist">Disturbed</em></p>,
#  <p class="title-artist"><cite class="title">Love Shack</cite><em class="artist">The B-52's</em></p>,
#  <p class="title-artist"><cite class="title">I Like You (A Happier Song) [feat. Doja Cat]</cite><em class="artist">Post Malone</em></p>,
#  <p class="title-artist"><cite class="title">Son Of A Sinner</cite><em class="artist">Jelly Roll</em></p>,
#  <p class="title-artist"><cite class="title">Call Me Maybe</cite><em class="artist">Carly Rae Jepsen</em></p>,
#  <p class="title-artist"><cite class="title">Poker Face</cite><em class="artist">Lady Gaga</em></p>,
#  <p class="title-artist"><cite class="title">Fancy Like</cite><em class="artist">Walker Hayes</em></p>,
#  <p class="title-artist"><cite class="title">= (Equal Sign)</cite><em class="artist">j-hope</em></p>,
#  <p class="title-artist"><cite class="title">Hot Shit</cite><em class="artist">Cardi B, Kanye West &amp; Lil Durk</em></p>,
#  <p class="title-artist"><cite class="title">Glimpse of Us</cite><em class="artist">Joji</em></p>,
#  <p class="title-artist"><cite class="title">Big Energy (Remix) [feat. DJ Khaled]</cite><em class="artist">Latto &amp; Mariah Carey</em></p>,
#  <p class="title-artist"><cite class="title">'Til You Can't</cite><em class="artist">Cody Johnson</em></p>,
#  <p class="title-artist"><cite class="title">Don’t Come Lookin’</cite><em class="artist">Jackson Dean</em></p>,
#  <p class="title-artist"><cite class="title">Fall In Love</cite><em class="artist">Bailey Zimmerman</em></p>,
#  <p class="title-artist"><cite class="title">Never Gonna Give You Up</cite><em class="artist">Rick Astley</em></p>,
#  <p class="title-artist"><cite class="title">Can't Stop Us Now</cite><em class="artist">Pitbull &amp; Zac Brown</em></p>,
#  <p class="title-artist"><cite class="title">Cold Heart (PNAU Remix)</cite><em class="artist">Elton John &amp; Dua Lipa</em></p>,
#  <p class="title-artist"><cite class="title">Numb</cite><em class="artist">Marshmello &amp; Khalid</em></p>,
#  <p class="title-artist"><cite class="title">5 Foot 9</cite><em class="artist">Tyler Hubbard</em></p>,
#  <p class="title-artist"><cite class="title">Tennessee Whiskey</cite><em class="artist">Chris Stapleton</em></p>,
#  <p class="title-artist"><cite class="title">Pandora's Box</cite><em class="artist">j-hope</em></p>,
#  <p class="title-artist"><cite class="title">Lights (Single Version)</cite><em class="artist">Ellie Goulding</em></p>,
#  <p class="title-artist"><cite class="title">Late Night Talking</cite><em class="artist">Harry Styles</em></p>,
#  <p class="title-artist"><cite class="title">Safety Zone</cite><em class="artist">j-hope</em></p>,
#  <p class="title-artist"><cite class="title">Future</cite><em class="artist">j-hope</em></p>,
#  <p class="title-artist"><cite class="title">Special</cite><em class="artist">Lizzo</em></p>,
#  <p class="title-artist"><cite class="title">What If…</cite><em class="artist">j-hope</em></p>,
#  <p class="title-artist"><cite class="title">Dark Horse (feat. Juicy J)</cite><em class="artist">Katy Perry</em></p>,
#  <p class="title-artist"><cite class="title">Damn Strait</cite><em class="artist">Scotty McCreery</em></p>,
#  <p class="title-artist"><cite class="title">Vegas</cite><em class="artist">Doja Cat</em></p>,
#  <p class="title-artist"><cite class="title">Just the Way You Are (feat. Lupe Fiasco) [Remix] [Bonus Track]</cite><em class="artist">Bruno Mars</em></p>,
#  <p class="title-artist"><cite class="title">Sweet Caroline</cite><em class="artist">Neil Diamond</em></p>,
#  <p class="title-artist"><cite class="title">STOP</cite><em class="artist">j-hope</em></p>,
#  <p class="title-artist"><cite class="title">Everybody Wants to Rule the World</cite><em class="artist">Tears for Fears</em></p>,
#  <p class="title-artist"><cite class="title">I'm Yours</cite><em class="artist">Jason Mraz</em></p>,
#  <p class="title-artist"><cite class="title">Sweet Child O' Mine</cite><em class="artist">Guns N' Roses</em></p>,
#  <p class="title-artist"><cite class="title">When You're Gone</cite><em class="artist">Shawn Mendes</em></p>,
#  <p class="title-artist"><cite class="title">Roar</cite><em class="artist">Katy Perry</em></p>,
#  <p class="title-artist"><cite class="title">Music Box : Reflection</cite><em class="artist">j-hope</em></p>,
#  <p class="title-artist"><cite class="title">7 Years</cite><em class="artist">Lukas Graham</em></p>,
#  <p class="title-artist"><cite class="title">You</cite><em class="artist">Louyah</em></p>,
#  <p class="title-artist"><cite class="title">Dancing Queen</cite><em class="artist">ABBA</em></p>,
#  <p class="title-artist"><cite class="title">Grenade</cite><em class="artist">Bruno Mars</em></p>,
#  <p class="title-artist"><cite class="title">Shivers</cite><em class="artist">Ed Sheeran</em></p>,
#  <p class="title-artist"><cite class="title">Separate Ways (Worlds Apart) [Steve Perry &amp; Bryce Miller Extended Remix]</cite><em class="artist">Journey &amp; Steve Perry</em></p>,
#  <p class="title-artist"><cite class="title">Joy of My Life</cite><em class="artist">Chris Stapleton</em></p>,
#  <p class="title-artist"><cite class="title">The Motto</cite><em class="artist">Tiësto &amp; Ava Max</em></p>,
#  <p class="title-artist"><cite class="title">Something in the Orange (Z&amp;E's Version)</cite><em class="artist">Zach Bryan</em></p>,
#  <p class="title-artist"><cite class="title">Tití Me Preguntó</cite><em class="artist">Bad Bunny</em></p>,
#  <p class="title-artist"><cite class="title">Love Me More</cite><em class="artist">Sam Smith</em></p>,
#  <p class="title-artist"><cite class="title">Victoria’s Secret</cite><em class="artist">Jax</em></p>,
#  <p class="title-artist"><cite class="title">Intro</cite><em class="artist">j-hope</em></p>,
#  <p class="title-artist"><cite class="title">W.I.T.C.H.</cite><em class="artist">Devon Cole</em></p>,
#  <p class="title-artist"><cite class="title">Hold On</cite><em class="artist">Wilson Phillips</em></p>,
#  <p class="title-artist"><cite class="title">She Likes It (feat. Jake Scott)</cite><em class="artist">Russell Dickerson &amp; Jake Scott</em></p>,
#  <p class="title-artist"><cite class="title">Kings &amp; Queens</cite><em class="artist">Ava Max</em></p>,
#  <p class="title-artist"><cite class="title">Sand In My Boots</cite><em class="artist">Morgan Wallen</em></p>,
#  <p class="title-artist"><cite class="title">Hot n Cold</cite><em class="artist">Katy Perry</em></p>,
#  <p class="title-artist"><cite class="title">Wild Palomino</cite><em class="artist">Zac Brown Band &amp; Cody Johnson</em></p>,
#  <p class="title-artist"><cite class="title">When I Was Your Man</cite><em class="artist">Bruno Mars</em></p>,
#  <p class="title-artist"><cite class="title">Danger Zone</cite><em class="artist">Kenny Loggins</em></p>,
#  <p class="title-artist"><cite class="title">Take My Name</cite><em class="artist">Parmalee</em></p>,
#  <p class="title-artist"><cite class="title">Running up That Hill (A Deal with God)</cite><em class="artist">Loveless</em></p>,
#  <p class="title-artist"><cite class="title">Vegas (From the Original Motion Picture Soundtrack ELVIS)</cite><em class="artist">Doja Cat</em></p>,
#  <p class="title-artist"><cite class="title">Heat Waves</cite><em class="artist">Glass Animals</em></p>,
#  <p class="title-artist"><cite class="title">Numb Little Bug</cite><em class="artist">Em Beihold</em></p>,
#  <p class="title-artist"><cite class="title">Levitating (feat. DaBaby)</cite><em class="artist">Dua Lipa</em></p>,
#  <p class="title-artist"><cite class="title">Big Energy</cite><em class="artist">Latto</em></p>,
#  <p class="title-artist"><cite class="title">Soul</cite><em class="artist">Lee Brice</em></p>,
#  <p class="title-artist"><cite class="title">abcdefu (feat. Royal &amp; the Serpent)</cite><em class="artist">GAYLE</em></p>,
#  <p class="title-artist"><cite class="title">Carolina (From The Motion Picture “Where The Crawdads Sing”)</cite><em class="artist">Taylor Swift</em></p>,
#  <p class="title-artist"><cite class="title">Buy Dirt (feat. Luke Bryan)</cite><em class="artist">Jordan Davis</em></p>,
#  <p class="title-artist"><cite class="title">Hold My Hand (Music From The Motion Picture "Top Gun: Maverick")</cite><em class="artist">Lady Gaga</em></p>]

# %%
soup.select("p.title-artist")[0].get_text()
# Out:
# 'About Damn TimeLizzo'

# %%
soup.select("p.title-artist cite.title")[0].get_text()
# Out:
# 'About Damn Time'

# %%
soup.select("p.title-artist em.artist")[0].get_text()
# Out:
# 'Lizzo'

# %%
#initialize empty lists
song = []
artist = []


# define the number of iterations of our for loop
# by checking how many elements are in the retrieved result set
# (this is equivalent but more robust than just explicitly defining 250 iterations)
num_iter = len(soup.select("p.title-artist"))

tClist = soup.select("p.title-artist cite.title")
citelist = soup.select("p.title-artist em.artist")
# iterate through the result set and retrive all the data
for i in range(num_iter):
    song.append(tClist[i].get_text())
    artist.append(citelist[i].get_text())


print(song)
print(artist)
# Out:
# ['About Damn Time', 'Running Up That Hill (A Deal with God)', "Y'all Life", 'Names', 'BREAK MY SOUL', 'As It Was', 'The Kind of Love We Make', 'She Had Me At Heads Carolina', 'Unstoppable', 'About Damn Time', 'Quietly Yours', "I Ain't Worried", 'Wasted On You', 'Rock and A Hard Place', 'Irrelevant', 'Good as Hell', 'Arson', 'Party In the U.S.A.', 'Master of Puppets', 'Like I Love Country Music', 'Left and Right', 'Sunroof', 'You Proof', 'Hold My Hand', 'Stay With Me', 'AA', 'First Class', 'Hey You', 'Love Shack', 'I Like You (A Happier Song) [feat. Doja Cat]', 'Son Of A Sinner', 'Call Me Maybe', 'Poker Face', 'Fancy Like', '= (Equal Sign)', 'Hot Shit', 'Glimpse of Us', 'Big Energy (Remix) [feat. DJ Khaled]', "'Til You Can't", 'Don’t Come Lookin’', 'Fall In Love', 'Never Gonna Give You Up', "Can't Stop Us Now", 'Cold Heart (PNAU Remix)', 'Numb', '5 Foot 9', 'Tennessee Whiskey', "Pandora's Box", 'Lights (Single Version)', 'Late Night Talking', 'Safety Zone', 'Future', 'Special', 'What If…', 'Dark Horse (feat. Juicy J)', 'Damn Strait', 'Vegas', 'Just the Way You Are (feat. Lupe Fiasco) [Remix] [Bonus Track]', 'Sweet Caroline', 'STOP', 'Everybody Wants to Rule the World', "I'm Yours", "Sweet Child O' Mine", "When You're Gone", 'Roar', 'Music Box : Reflection', '7 Years', 'You', 'Dancing Queen', 'Grenade', 'Shivers', 'Separate Ways (Worlds Apart) [Steve Perry & Bryce Miller Extended Remix]', 'Joy of My Life', 'The Motto', "Something in the Orange (Z&E's Version)", 'Tití Me Preguntó', 'Love Me More', 'Victoria’s Secret', 'Intro', 'W.I.T.C.H.', 'Hold On', 'She Likes It (feat. Jake Scott)', 'Kings & Queens', 'Sand In My Boots', 'Hot n Cold', 'Wild Palomino', 'When I Was Your Man', 'Danger Zone', 'Take My Name', 'Running up That Hill (A Deal with God)', 'Vegas (From the Original Motion Picture Soundtrack ELVIS)', 'Heat Waves', 'Numb Little Bug', 'Levitating (feat. DaBaby)', 'Big Energy', 'Soul', 'abcdefu (feat. Royal & the Serpent)', 'Carolina (From The Motion Picture “Where The Crawdads Sing”)', 'Buy Dirt (feat. Luke Bryan)', 'Hold My Hand (Music From The Motion Picture "Top Gun: Maverick")']
# ['Lizzo', 'Kate Bush', 'Walker Hayes', 'Tom MacDonald', 'Beyoncé', 'Harry Styles', 'Luke Combs', 'Cole Swindell', 'Sia', 'Lizzo', 'Birdy', 'OneRepublic', 'Morgan Wallen', 'Bailey Zimmerman', 'P!nk', 'Lizzo', 'j-hope', 'Miley Cyrus', 'Metallica', 'Kane Brown', 'Charlie Puth & Jung Kook', 'Nicky Youre & Dazy', 'Morgan Wallen', 'Lady Gaga', 'Calvin Harris, Justin Timberlake, Halsey & Pharrell Williams', 'Walker Hayes', 'Jack Harlow', 'Disturbed', "The B-52's", 'Post Malone', 'Jelly Roll', 'Carly Rae Jepsen', 'Lady Gaga', 'Walker Hayes', 'j-hope', 'Cardi B, Kanye West & Lil Durk', 'Joji', 'Latto & Mariah Carey', 'Cody Johnson', 'Jackson Dean', 'Bailey Zimmerman', 'Rick Astley', 'Pitbull & Zac Brown', 'Elton John & Dua Lipa', 'Marshmello & Khalid', 'Tyler Hubbard', 'Chris Stapleton', 'j-hope', 'Ellie Goulding', 'Harry Styles', 'j-hope', 'j-hope', 'Lizzo', 'j-hope', 'Katy Perry', 'Scotty McCreery', 'Doja Cat', 'Bruno Mars', 'Neil Diamond', 'j-hope', 'Tears for Fears', 'Jason Mraz', "Guns N' Roses", 'Shawn Mendes', 'Katy Perry', 'j-hope', 'Lukas Graham', 'Louyah', 'ABBA', 'Bruno Mars', 'Ed Sheeran', 'Journey & Steve Perry', 'Chris Stapleton', 'Tiësto & Ava Max', 'Zach Bryan', 'Bad Bunny', 'Sam Smith', 'Jax', 'j-hope', 'Devon Cole', 'Wilson Phillips', 'Russell Dickerson & Jake Scott', 'Ava Max', 'Morgan Wallen', 'Katy Perry', 'Zac Brown Band & Cody Johnson', 'Bruno Mars', 'Kenny Loggins', 'Parmalee', 'Loveless', 'Doja Cat', 'Glass Animals', 'Em Beihold', 'Dua Lipa', 'Latto', 'Lee Brice', 'GAYLE', 'Taylor Swift', 'Jordan Davis', 'Lady Gaga']

# %%
# each list becomes a column
songs = pd.DataFrame({"song":song,
                       "artist":artist
                      })
#we provide a dictionary where the key is the name of the column, and values are the values inside the column

# %%
songs.head(10)
# Out:
#                                      song         artist
# 0                         About Damn Time          Lizzo
# 1  Running Up That Hill (A Deal with God)      Kate Bush
# 2                              Y'all Life   Walker Hayes
# 3                                   Names  Tom MacDonald
# 4                           BREAK MY SOUL        Beyoncé
# 5                               As It Was   Harry Styles
# 6                The Kind of Love We Make     Luke Combs
# 7            She Had Me At Heads Carolina  Cole Swindell
# 8                             Unstoppable            Sia
# 9                         About Damn Time          Lizzo

# %%
len(songs)
# Out:
# 100

# %%
# !git add .

# %%
# !git commit -m "Web Scraping Lab 1 Finalized"
# Out:
# [master 8e57a31] Web Scraping Lab 1 Finalized
#  3 files changed, 7234 insertions(+), 540 deletions(-)
#  create mode 100644 .ipynb_checkpoints/Web Scraping Single Page-checkpoint.ipynb

# %%
# !git push
# Out:
# Counting objects: 5, done.
# Delta compression using up to 4 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 199.23 KiB | 701.00 KiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/hollyjanedalton/lab-cleaning-numerical-categorical-data.git
#    7b43721..8e57a31  master -> master

# %% [markdown]
# # Lab 2 | Web Scraping Multiple Pages

# %%
#Lab 2

#expand the list by scraping the 100 top songs from a different website source, creating a diff dataframe
#be aware some websites are difficult to scrape, at least do one other website


#Practice web scraping section:
#just pick 2, one can be from wikipedia, don't have to do all 7

# %%
url_2 = "https://www.officialcharts.com/charts/singles-chart/"

# %%
response_2 = requests.get(url_2)

# %%
response_2.status_code
# Out:
# 200

# %%
len(response_2.content)
# Out:
# 452955

# %%
soup_1 = BeautifulSoup(response_2.content, "html.parser")

# %%
soup_1

# %%
print(soup_1.select("div.title")[0].get_text())
# Out:
# AFRAID TO FEEL

# %%
print(soup_1.select("div.artist")[0].get_text())
# Out:
# LF SYSTEM

# %%
title2=[]
artist2=[]

title_list2=soup1.select("div.title a")
artist_list2=soup1.select("div.artist a")


num_iter2 = len(soup1.select("div.artist a"))

for i in range(num_iter2):
    title2.append(title_list2[i].get_text())
    artist2.append(artist_list2[i].get_text())
    
print (title2)
print (artist2)

# %%
song_2 = []
artist_2 = []

song_list2 = soup_1.select("div.title a")
artist_list2 = soup_1.select("div.artist a")


num_iter2 = len(soup_1.select("div.title a"))


# iterate through the result set and retrive all the data
for i in range(num_iter2):
    song_2.append(song_list2[i].get_text())
    artist_2.append(artist_list2[i].get_text())


print(song_2)
print(artist_2)
# Out:
# ['AFRAID TO FEEL', 'AS IT WAS', 'GREEN GREEN GRASS', 'BREAK MY SOUL', 'RUNNING UP THAT HILL', 'ABOUT DAMN TIME', 'LAST LAST', 'CRAZY WHAT LOVE CAN DO', 'IFTK', '21 REASONS', 'MASSIVE', 'WHERE DID YOU GO', 'LATE NIGHT TALKING', "I AIN'T WORRIED", 'SEVENTEEN GOING UNDER', 'GLIMPSE OF US', 'STAY THE NIGHT', 'WAIT FOR U', 'MUSIC FOR A SUSHI RESTAURANT', 'GO', 'NO EXCUSES', 'MASTER OF PUPPETS', 'JIMMY COOKS', 'POTION', 'VEGAS', 'BIG ENERGY', 'HOLD MY HAND', 'I LIKE YOU (A HAPPIER SONG)', 'HOT IN IT', 'FOR MY HAND', 'ELEGANT & GANG', "DON'T FORGET MY LOVE", 'HEAT WAVES', 'REMIND ME', 'BAD HABITS', 'PERU', '2STEP', 'IN THE STARS', 'SHIVERS', 'WHERE ARE YOU NOW', 'HAPPIER THAN EVER', 'FLOWERS', 'SUNROOF', 'MIXED EMOTIONS', 'RAINFALL', 'MAKE ME FEEL GOOD', 'CLOAK & DAGGER', 'BAM BAM', 'SOMETHING TO SOMEONE', "JE M'APPELLE", 'FIRST CLASS', 'STICKY', 'COLD HEART', 'FERRARI', 'BIG CITY LIFE', 'SPACE MAN', 'PART OF THE BAND', 'BABY', 'COOPED UP', 'STRANGERS', 'MR BRIGHTSIDE', "SHE'S ALL I WANNA BE", 'THROUGH THE ECHOES', 'STFU', 'DANDELIONS', 'LEFT AND RIGHT', 'SNAP', 'STARLIGHT', 'BAD HABIT', 'BRAZIL', 'BAD LIFE', 'LOOSE CHANGE', 'BETTY (GET MONEY)', 'HOUSE ON FIRE', 'ONE KISS', 'WORDS', 'GETTING STARTED', 'ANYONE FOR YOU', 'CALL ME EVERY DAY', 'WET DREAM', 'SHOTGUN', 'JUNGLE', 'STAY', 'SAVE YOUR TEARS', 'BMW', 'DOWN UNDER', 'HEAVEN TAKES YOU HOME', 'LEVITATING', 'BLINDING LIGHTS', "MAYBE YOU'RE THE PROBLEM", 'GOOD 4 U', 'I WILL SURVIVE', '1989', 'FINESSE', 'EVERYBODY WANTS TO RULE THE WORLD', 'ALL MINE', 'HATE IT OR LOVE IT', 'HOT S**T', 'SOMEONE YOU LOVED', 'RIPTIDE']
# ['LF SYSTEM', 'HARRY STYLES', 'GEORGE EZRA', 'BEYONCE', 'KATE BUSH', 'LIZZO', 'BURNA BOY', 'DAVID GUETTA/HILL/HENDERSON', 'TION WAYNE & LA ROUX', 'NATHAN DAWE FT ELLA HENDERSON', 'DRAKE', 'JAX JONES FT MNEK', 'HARRY STYLES', 'ONEREPUBLIC', 'SAM FENDER', 'JOJI', 'SIGALA & TALIA MAR', 'FUTURE FT DRAKE & TEMS', 'HARRY STYLES', 'CAT BURNS', 'BRU-C', 'METALLICA', 'DRAKE FT 21 SAVAGE', 'CALVIN HARRIS/DUA LIPA/YOUNG', 'DOJA CAT', 'LATTO/MARIAH CAREY/DJ KHALED', 'LADY GAGA', 'POST MALONE FT DOJA CAT', 'TIESTO & CHARLI XCX', 'BURNA BOY FT ED SHEERAN', 'D-BLOCK EUROPE/GHOST KILLER', 'DIPLO & MIGUEL', 'GLASS ANIMALS', 'TOM GRENNAN', 'ED SHEERAN', 'FIREBOY DML & ED SHEERAN', 'ED SHEERAN', 'BENSON BOONE', 'ED SHEERAN', 'LOST FREQUENCIES/CALUM SCOTT', 'BILLIE EILISH', 'LAUREN SPENCER-SMITH', 'NICKY YOURE & DAZY', 'CHASE & STATUS', 'TOM SANTA', 'BELTERS ONLY FT JAZZY', 'BURNA BOY FT J HUS', 'CAMILA CABELLO FT ED SHEERAN', 'DERMOT KENNEDY', 'BENZZ', 'JACK HARLOW', 'DRAKE', 'ELTON JOHN & DUA LIPA', 'JAMES HYPE/MIGGY DELA ROSA', 'LUUDE & MATTAFIX', 'SAM RYDER', '1975', 'AITCH/ASHANTI', 'POST MALONE FT RODDY RICCH', 'BRING ME THE HORIZON', 'KILLERS', 'TATE MCRAE', 'PAOLO NUTINI', 'DIGGA D', 'RUTH B', 'CHARLIE PUTH FT JUNG KOOK', 'ROSA LINN', 'DAVE', 'STEVE LACY', 'DECLAN MCKENNA', 'SIGRID & BRING ME THE HORIZON', 'BRENT FAIYAZ', 'YUNG GRAVY', 'MIMI WEBB', 'CALVIN HARRIS & DUA LIPA', 'ALESSO/ZARA LARSSON', 'SAM FENDER', 'GEORGE EZRA', 'CHRIS BROWN FT WIZKID', 'WET LEG', 'GEORGE EZRA', 'FRED AGAIN', 'KID LAROI & JUSTIN BIEBER', 'WEEKND', 'BAD BOY CHILLER CREW', 'LUUDE FT COLIN HAY', 'SWEDISH HOUSE MAFIA', 'DUA LIPA', 'WEEKND', 'AVA MAX', 'OLIVIA RODRIGO', 'BELTERS ONLY', 'AITCH', 'PHEELZ & BNXN', 'TEARS FOR FEARS', 'BRENT FAIYAZ', 'GAME FT 50 CENT', 'CARDI B/KANYE WEST/LIL DURK', 'LEWIS CAPALDI', 'VANCE JOY']

# %%
songs_2 = pd.DataFrame({"song":song_2,
                       "artist":artist_2
                      })

# %%
songs_2.head(20)
# Out:
#                             song                         artist
# 0                 AFRAID TO FEEL                      LF SYSTEM
# 1                      AS IT WAS                   HARRY STYLES
# 2              GREEN GREEN GRASS                    GEORGE EZRA
# 3                  BREAK MY SOUL                        BEYONCE
# 4           RUNNING UP THAT HILL                      KATE BUSH
# 5                ABOUT DAMN TIME                          LIZZO
# 6                      LAST LAST                      BURNA BOY
# 7         CRAZY WHAT LOVE CAN DO    DAVID GUETTA/HILL/HENDERSON
# 8                           IFTK           TION WAYNE & LA ROUX
# 9                     21 REASONS  NATHAN DAWE FT ELLA HENDERSON
# 10                       MASSIVE                          DRAKE
# 11              WHERE DID YOU GO              JAX JONES FT MNEK
# 12            LATE NIGHT TALKING                   HARRY STYLES
# 13               I AIN'T WORRIED                    ONEREPUBLIC
# 14         SEVENTEEN GOING UNDER                     SAM FENDER
# 15                 GLIMPSE OF US                           JOJI
# 16                STAY THE NIGHT             SIGALA & TALIA MAR
# 17                    WAIT FOR U         FUTURE FT DRAKE & TEMS
# 18  MUSIC FOR A SUSHI RESTAURANT                   HARRY STYLES
# 19                            GO                      CAT BURNS

# %% [markdown]
# ### Practice web scraping

# %%
#1 Create a Python list with the top ten FBI's Most Wanted names: 
#url = 'https://www.fbi.gov/wanted/topten'

# %%
# !git add .

# %%
# !git commit -m "Almost done Web Scraping labs"
# Out:
# [master e2e4dd1] Almost done Web Scraping labs
#  2 files changed, 210 insertions(+), 70 deletions(-)

# %%
# !git push
# Out:
# Counting objects: 4, done.
# Delta compression using up to 4 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.21 KiB | 248.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/hollyjanedalton/lab-cleaning-numerical-categorical-data.git
#    86f8bad..e2e4dd1  master -> master

# %%
url = "https://www.fbi.gov/wanted/topten"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
len(response.content)
# Out:
# 71502

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
print(soup.select("h3.title a")[0].get_text())
# Out:
# JASON DEREK BROWN

# %%
fbi = []

mostwanted_list = soup.select("h3.title a")


num_iter = len(soup.select("h3.title a"))


# iterate through the result set and retrive all the data
for i in range(num_iter):
    fbi.append(mostwanted_list[i].get_text())


print(fbi)
# Out:
# ['JASON DEREK BROWN', 'RUJA IGNATOVA', 'ARNOLDO JIMENEZ', 'ALEXIS FLORES', 'JOSE RODOLFO VILLARREAL-HERNANDEZ', 'YULAN ADONAY ARCHAGA CARIAS', 'RAFAEL CARO-QUINTERO', 'EUGENE PALMER', 'BHADRESHKUMAR CHETANBHAI PATEL', 'ALEJANDRO ROSALES CASTILLO']

# %%
criminals = pd.DataFrame({"criminal_name":fbi,
                      })
criminals
# Out:
#                        criminal_name
# 0                  JASON DEREK BROWN
# 1                      RUJA IGNATOVA
# 2                    ARNOLDO JIMENEZ
# 3                      ALEXIS FLORES
# 4  JOSE RODOLFO VILLARREAL-HERNANDEZ
# 5        YULAN ADONAY ARCHAGA CARIAS
# 6               RAFAEL CARO-QUINTERO
# 7                      EUGENE PALMER
# 8     BHADRESHKUMAR CHETANBHAI PATEL
# 9         ALEJANDRO ROSALES CASTILLO

# %%
#2 Display the top 10 languages by number of native speakers stored in a pandas dataframe: 
#url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
url = "https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
len(response.content)
# Out:
# 166010

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
print(soup.select("td a")[0].get_text())
# Out:
# Mandarin Chinese

# %%
print(soup.select("td:nth-child(3)")[0].get_text())

#mw-content-text > div.mw-parser-output > table:nth-child(15) > tbody > tr:nth-child(1) > td:nth-child(3)
# Out:
# 929.0

# %%
top10_languages = []
spkrs_millions = []

top10_languages_list = soup.select("td a")
spkrs_millions_list = soup.select("td:nth-child(3)")

num_iter = len(soup.select("td:nth-child(3)"))


# iterate through the result set and retrieve all the data
for i in range(num_iter):
    top10_languages.append(top10_languages_list[i].get_text())
    spkrs_millions.append(spkrs_millions_list[i].get_text())

top10 = top10_languages[:10]
speakers = spkrs_millions[:10]
print(top10)
print(speakers)
# Out:
# ['Mandarin Chinese', 'Sino-Tibetan', 'Sinitic', 'Spanish', 'Indo-European', 'Romance', 'English', 'Indo-European', 'Germanic', 'Hindi']
# ['929.0\n', '474.7\n', '372.9\n', '343.9\n', '233.7\n', '232.4\n', '154.0\n', '125.3\n', '92.7\n', '85.2\n']

# %%
top_languages = pd.DataFrame({"language":top10,
                              "speakers (in millions)": speakers
                      })
top_languages
# Out:
#            language speakers (in millions)
# 0  Mandarin Chinese                929.0\n
# 1      Sino-Tibetan                474.7\n
# 2           Sinitic                372.9\n
# 3           Spanish                343.9\n
# 4     Indo-European                233.7\n
# 5           Romance                232.4\n
# 6           English                154.0\n
# 7     Indo-European                125.3\n
# 8          Germanic                 92.7\n
# 9             Hindi                 85.2\n

# %%
##Why returning the \n??

# %%
# !git add .

# %%
# !git commit -m "Almost done Web Scraping labs"

# %%
# !git push
