# %% [markdown]
# ## Lab | Creating First Prototype

# %%
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://www.popvortex.com/music/charts/top-100-songs.php"

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
len(response.content)
# Out:
# 364847

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup

# %%
soup.select("p.title-artist")

# %%
soup.select("p.title-artist cite.title")[0].get_text()

# %%
soup.select("p.title-artist em.artist")[0].get_text()

# %%
#initialize empty lists
song_title = []
artist = []


# define the number of iterations of our for loop
# by checking how many elements are in the retrieved result set
# (this is equivalent but more robust than just explicitly defining 250 iterations)
num_iter = len(soup.select("p.title-artist"))

song_list = soup.select("p.title-artist cite.title")
artist_list = soup.select("p.title-artist em.artist")
# iterate through the result set and retrive all the data
for i in range(num_iter):
    song_title.append(song_list[i].get_text())
    artist.append(artist_list[i].get_text())


print(song_title)
print(artist)
# Out:
# ['About Damn Time', 'Running Up That Hill (A Deal with God)', 'TV', 'You Can Have Him Jolene', "Y'all Life", 'The Kind of Love We Make', 'As It Was', 'Miracle', 'BREAK MY SOUL', 'Rock and A Hard Place', 'She Had Me At Heads Carolina', 'Irrelevant', 'Wasted On You', 'Names', 'Unstoppable', 'Left and Right', 'Good as Hell', 'The Dying Song (Time To Sing)', "I Ain't Worried", 'You Proof', 'About Damn Time', "Can't Stop Us Now", 'Sunroof', 'Becky’s So Hot', 'Victoria’s Secret', 'Like I Love Country Music', 'Everybody Wants to Rule the World', 'Party In the U.S.A.', 'Never Gonna Give You Up', 'Master of Puppets', 'I Like You (A Happier Song) [feat. Doja Cat]', 'Arson', 'First Class', 'Hold My Hand', 'Fall In Love', 'Son Of A Sinner', 'Never Til Now', 'Vegas (From the Original Motion Picture Soundtrack ELVIS)', 'Numb', 'Glimpse of Us', 'AA', 'Hot Shit', 'American Pie (Full Length Version)', 'Dancing Queen', '5 Foot 9', 'Late Night Talking', "'Til You Can't", 'Damn Strait', 'Fancy Like', 'Quietly Yours', 'Cold Heart (PNAU Remix)', 'Don’t Come Lookin’', 'Call Me Maybe', 'Valley of Lies', 'You Can Have Him Jolene', 'Tennessee Whiskey', 'Poker Face', '= (Equal Sign)', 'Shivers', "Don't Stop Believin'", 'Safety Zone', "Pandora's Box", 'She Likes It (feat. Jake Scott)', 'What If…', 'STOP', 'Future', 'Betty (Get Money)', 'Lights (Single Version)', "Sweet Child O' Mine", 'Soul', 'Music Box : Reflection', "Something in the Orange (Z&E's Version)", 'Hey You', 'Intro', 'Sweet Caroline', 'Dark Horse (feat. Juicy J)', 'Roar', 'MORE', '7 Years', 'Big Energy (Remix) [feat. DJ Khaled]', 'Numb Little Bug', 'WAIT FOR U (feat. Drake & Tems)', 'Big Energy', "I'm Yours", 'Tití Me Preguntó', 'Joy of My Life', 'Whiskey On You', 'Angel (feat. Rayvon)', 'The 30th', 'Heat Waves', 'abcdefu (feat. Royal & the Serpent)', 'Sand In My Boots', 'Levitating (feat. DaBaby)', 'Kings & Queens', 'Country On', 'In Jesus Name (God Of Possible)', 'Jimmy Cooks (feat. 21 Savage)', 'Love Shack', 'Take My Name', 'So Good']
# ['Lizzo', 'Kate Bush', 'Billie Eilish', 'Chapel Hart', 'Walker Hayes', 'Luke Combs', 'Harry Styles', 'A Day to Remember', 'Beyoncé', 'Bailey Zimmerman', 'Cole Swindell', 'P!nk', 'Morgan Wallen', 'Tom MacDonald', 'Sia', 'Charlie Puth & Jung Kook', 'Lizzo', 'Slipknot', 'OneRepublic', 'Morgan Wallen', 'Lizzo', 'Pitbull & Zac Brown', 'Nicky Youre & Dazy', 'FLETCHER', 'Jax', 'Kane Brown', 'Tears for Fears', 'Miley Cyrus', 'Rick Astley', 'Metallica', 'Post Malone', 'j-hope', 'Jack Harlow', 'Lady Gaga', 'Bailey Zimmerman', 'Jelly Roll', 'Ashley Cooke & Brett Young', 'Doja Cat', 'Marshmello & Khalid', 'Joji', 'Walker Hayes', 'Cardi B, Kanye West & Lil Durk', 'Don Mclean', 'ABBA', 'Tyler Hubbard', 'Harry Styles', 'Cody Johnson', 'Scotty McCreery', 'Walker Hayes', 'Birdy', 'Elton John & Dua Lipa', 'Jackson Dean', 'Carly Rae Jepsen', 'TOMORROW X TOGETHER & iann dior', 'Chapel Hart', 'Chris Stapleton', 'Lady Gaga', 'j-hope', 'Ed Sheeran', 'Journey', 'j-hope', 'j-hope', 'Russell Dickerson & Jake Scott', 'j-hope', 'j-hope', 'j-hope', 'Yung Gravy', 'Ellie Goulding', "Guns N' Roses", 'Lee Brice', 'j-hope', 'Zach Bryan', 'Disturbed', 'j-hope', 'Neil Diamond', 'Katy Perry', 'Katy Perry', 'j-hope', 'Lukas Graham', 'Latto & Mariah Carey', 'Em Beihold', 'Future', 'Latto', 'Jason Mraz', 'Bad Bunny', 'Chris Stapleton', 'Nate Smith', 'Shaggy', 'Billie Eilish', 'Glass Animals', 'GAYLE', 'Morgan Wallen', 'Dua Lipa', 'Ava Max', 'Luke Bryan', 'Katy Nichole', 'Drake', "The B-52's", 'Parmalee', 'Halsey']

# %%
# each list becomes a column
top100 = pd.DataFrame({"song_title":song_title,
                       "artist":artist
                      })
#we provide a dictionary where the key is the name of the column, and values are the values inside the column

# %%
top100.head(50)
# Out:
#                                            song_title  \
# 0                                     About Damn Time
# 1              Running Up That Hill (A Deal with God)
# 2                                                  TV
# 3                             You Can Have Him Jolene
# 4                                          Y'all Life
# 5                            The Kind of Love We Make
# 6                                           As It Was
# 7                                             Miracle
# 8                                       BREAK MY SOUL
# 9                               Rock and A Hard Place
# 10                       She Had Me At Heads Carolina
# 11                                         Irrelevant
# 12                                      Wasted On You
# 13                                              Names
# 14                                        Unstoppable
# 15                                     Left and Right
# 16                                       Good as Hell
# 17                      The Dying Song (Time To Sing)
# 18                                    I Ain't Worried
# 19                                          You Proof
# 20                                    About Damn Time
# 21                                  Can't Stop Us Now
# 22                                            Sunroof
# 23                                     Becky’s So Hot
# 24                                  Victoria’s Secret
# 25                          Like I Love Country Music
# 26                  Everybody Wants to Rule the World
# 27                                Party In the U.S.A.
# 28                            Never Gonna Give You Up
# 29                                  Master of Puppets
# 30       I Like You (A Happier Song) [feat. Doja Cat]
# 31                                              Arson
# 32                                        First Class
# 33                                       Hold My Hand
# 34                                       Fall In Love
# 35                                    Son Of A Sinner
# 36                                      Never Til Now
# 37  Vegas (From the Original Motion Picture Soundt...
# 38                                               Numb
# 39                                      Glimpse of Us
# 40                                                 AA
# 41                                           Hot Shit
# 42                 American Pie (Full Length Version)
# 43                                      Dancing Queen
# 44                                           5 Foot 9
# 45                                 Late Night Talking
# 46                                     'Til You Can't
# 47                                        Damn Strait
# 48                                         Fancy Like
# 49                                      Quietly Yours
#
#                             artist
# 0                            Lizzo
# 1                        Kate Bush
# 2                    Billie Eilish
# 3                      Chapel Hart
# 4                     Walker Hayes
# 5                       Luke Combs
# 6                     Harry Styles
# 7                A Day to Remember
# 8                          Beyoncé
# 9                 Bailey Zimmerman
# 10                   Cole Swindell
# 11                            P!nk
# 12                   Morgan Wallen
# 13                   Tom MacDonald
# 14                             Sia
# 15        Charlie Puth & Jung Kook
# 16                           Lizzo
# 17                        Slipknot
# 18                     OneRepublic
# 19                   Morgan Wallen
# 20                           Lizzo
# 21             Pitbull & Zac Brown
# 22              Nicky Youre & Dazy
# 23                        FLETCHER
# 24                             Jax
# 25                      Kane Brown
# 26                 Tears for Fears
# 27                     Miley Cyrus
# 28                     Rick Astley
# 29                       Metallica
# 30                     Post Malone
# 31                          j-hope
# 32                     Jack Harlow
# 33                       Lady Gaga
# 34                Bailey Zimmerman
# 35                      Jelly Roll
# 36      Ashley Cooke & Brett Young
# 37                        Doja Cat
# 38             Marshmello & Khalid
# 39                            Joji
# 40                    Walker Hayes
# 41  Cardi B, Kanye West & Lil Durk
# 42                      Don Mclean
# 43                            ABBA
# 44                   Tyler Hubbard
# 45                    Harry Styles
# 46                    Cody Johnson
# 47                 Scotty McCreery
# 48                    Walker Hayes
# 49                           Birdy

# %%
top100.to_csv('top100.csv')

# %%
import random

# %%
#https://albertoviciana.medium.com/my-first-song-recommender-96994af6d6bc

#we found code for this lab above

# %%
def song_recommender():
    random_song=random.choice(Top100['song_title'])
    user_input= input("Please type in your favorite hit song, capitalizing each word (example: 'Heat Waves'): ")
    
    
    if user_input not in list(Top100['song_title']):
        print("I don't have a recommendation for you.")
    else:
        print("If you like the song " + "'" + user_input + "'" + " then listen to this next: " + "'" + random_song + "'")

# %%
song_recommender()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [111], in <cell line: 1>()
# ----> 1 song_recommender()
#
# Input In [110], in song_recommender()
#       1 def song_recommender():
#       2     random_song=random.choice(Top100['song_title'])
# ----> 3     user_input= input("Please type in your favorite hit song, capitalizing each word (example: 'Heat Waves'): ")
#       6     if user_input not in list(Top100['song_title']):
#       7         print("I don't have a recommendation for you.")
#
# File /opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# File /opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1120, in Kernel._input_request(self, prompt, ident, parent, password)
#    1117             break
#    1118 except KeyboardInterrupt:
#    1119     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1120     raise KeyboardInterrupt("Interrupted by user") from None
#    1121 except Exception:
#    1122     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Lab | API wrappers - Create your collection of songs & audio features

# %% [markdown]
# To move forward with the project, you need to create a collection of songs
# with their audio features - as large as possible!
# An idea for collecting as many songs as possible is to start with
# all the songs of a big, diverse playlist and then go to every artist present
# in the playlist and grab every song of every album of that artist.
# The amount of songs you'll be collecting per playlist will grow exponentially!

# %% [markdown]
# Spotify objects are identified by either a "url", a "uri" or an "id".
#
# The id is an alphanumeric code, and it's the nuclear part of the identifier.
#
# The uri contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# The url is a link to the song on the Spotify web player.

# %%
#!pip install spotipy

# %% [markdown]
# #### Authentification

# %%
import spotipy   #the library
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
#sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id='<your client id here>',
#                                                           client_secret='<your client secret here>'))

# %% [markdown]
# #### storing secrets

# %%
secrets_file = open("/Users/hollydalton/Downloads/secrets.txt","r")

# %%
string = secrets_file.read()

# %%
string

# %%
string.split('\n')

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
secrets_dict

# %% [markdown]
# #### authentication with secrets

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['csecret']))

# %% [markdown]
# Handling large playlists

# %%
playlist = sp.user_playlist_tracks("spotify", "1G8IpkZKobrIlXcVPoSIuf")

# %%
playlist["total"]
# Out:
# 10000

# %%
playlist['next']  #gives next page of songs
# Out:
# 'https://api.spotify.com/v1/playlists/1G8IpkZKobrIlXcVPoSIuf/tracks?offset=100&limit=100&additional_types=track'

# %%
sp.next(playlist)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/1G8IpkZKobrIlXcVPoSIuf/tracks?offset=100&limit=100&additional_types=track',
#  'items': [{'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1nJvji2KIlWSseXRSlNYsC'},
#        'href': 'https://api.spotify.com/v1/artists/1nJvji2KIlWSseXRSlNYsC',
#        'id': '1nJvji2KIlWSseXRSlNYsC',
#        'name': 'The Velvet Underground',
#        'type': 'artist',
#        'uri': 'spotify:artist:1nJvji2KIlWSseXRSlNYsC'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0IwlY33zbBXN7zlS9DP2Cj'},
#        'href': 'https://api.spotify.com/v1/artists/0IwlY33zbBXN7zlS9DP2Cj',
#        'id': '0IwlY33zbBXN7zlS9DP2Cj',
#        'name': 'Nico',
#        'type': 'artist',
#        'uri': 'spotify:artist:0IwlY33zbBXN7zlS9DP2Cj'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3o7MFtKiZazZfZnW7dqwHA'},
#      'href': 'https://api.spotify.com/v1/albums/3o7MFtKiZazZfZnW7dqwHA',
#      'id': '3o7MFtKiZazZfZnW7dqwHA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ea94c1f22005932ec61d66b5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ea94c1f22005932ec61d66b5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ea94c1f22005932ec61d66b5',
#        'width': 64}],
#      'name': 'The Velvet Underground & Nico 45th Anniversary (Deluxe Edition)',
#      'release_date': '1967-03-12',
#      'release_date_precision': 'day',
#      'total_tracks': 31,
#      'type': 'album',
#      'uri': 'spotify:album:3o7MFtKiZazZfZnW7dqwHA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1nJvji2KIlWSseXRSlNYsC'},
#       'href': 'https://api.spotify.com/v1/artists/1nJvji2KIlWSseXRSlNYsC',
#       'id': '1nJvji2KIlWSseXRSlNYsC',
#       'name': 'The Velvet Underground',
#       'type': 'artist',
#       'uri': 'spotify:artist:1nJvji2KIlWSseXRSlNYsC'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0IwlY33zbBXN7zlS9DP2Cj'},
#       'href': 'https://api.spotify.com/v1/artists/0IwlY33zbBXN7zlS9DP2Cj',
#       'id': '0IwlY33zbBXN7zlS9DP2Cj',
#       'name': 'Nico',
#       'type': 'artist',
#       'uri': 'spotify:artist:0IwlY33zbBXN7zlS9DP2Cj'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 433573,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USPR36702765'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2SdDQZ4WupgDZP6eykOHHY'},
#     'href': 'https://api.spotify.com/v1/tracks/2SdDQZ4WupgDZP6eykOHHY',
#     'id': '2SdDQZ4WupgDZP6eykOHHY',
#     'is_local': False,
#     'name': 'Heroin',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:2SdDQZ4WupgDZP6eykOHHY'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2zyz0VJqrDXeFDIyrfVXSo'},
#        'href': 'https://api.spotify.com/v1/artists/2zyz0VJqrDXeFDIyrfVXSo',
#        'id': '2zyz0VJqrDXeFDIyrfVXSo',
#        'name': 'Jerry Lee Lewis',
#        'type': 'artist',
#        'uri': 'spotify:artist:2zyz0VJqrDXeFDIyrfVXSo'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/71dF2PBGuJ8iPlLblf9exZ'},
#      'href': 'https://api.spotify.com/v1/albums/71dF2PBGuJ8iPlLblf9exZ',
#      'id': '71dF2PBGuJ8iPlLblf9exZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c799f21750fdca0966fcaac1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c799f21750fdca0966fcaac1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c799f21750fdca0966fcaac1',
#        'width': 64}],
#      'name': 'The Very Best Of',
#      'release_date': '2008-06-10',
#      'release_date_precision': 'day',
#      'total_tracks': 59,
#      'type': 'album',
#      'uri': 'spotify:album:71dF2PBGuJ8iPlLblf9exZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2zyz0VJqrDXeFDIyrfVXSo'},
#       'href': 'https://api.spotify.com/v1/artists/2zyz0VJqrDXeFDIyrfVXSo',
#       'id': '2zyz0VJqrDXeFDIyrfVXSo',
#       'name': 'Jerry Lee Lewis',
#       'type': 'artist',
#       'uri': 'spotify:artist:2zyz0VJqrDXeFDIyrfVXSo'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 173866,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560788991'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3LUHtV6F7IHAOognkvcEKv'},
#     'href': 'https://api.spotify.com/v1/tracks/3LUHtV6F7IHAOognkvcEKv',
#     'id': '3LUHtV6F7IHAOognkvcEKv',
#     'is_local': False,
#     'name': "Whole Lotta Shakin' Goin' On",
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3LUHtV6F7IHAOognkvcEKv'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eqjTLE0HfPfh78zjh6TqT'},
#        'href': 'https://api.spotify.com/v1/artists/3eqjTLE0HfPfh78zjh6TqT',
#        'id': '3eqjTLE0HfPfh78zjh6TqT',
#        'name': 'Bruce Springsteen',
#        'type': 'artist',
#        'uri': 'spotify:artist:3eqjTLE0HfPfh78zjh6TqT'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2KwkK7CQpwprFOYh0t3aRw'},
#      'href': 'https://api.spotify.com/v1/albums/2KwkK7CQpwprFOYh0t3aRw',
#      'id': '2KwkK7CQpwprFOYh0t3aRw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27383d14c23eda568810851c3f2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0283d14c23eda568810851c3f2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485183d14c23eda568810851c3f2',
#        'width': 64}],
#      'name': 'Born To Run',
#      'release_date': '1975',
#      'release_date_precision': 'year',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:2KwkK7CQpwprFOYh0t3aRw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eqjTLE0HfPfh78zjh6TqT'},
#       'href': 'https://api.spotify.com/v1/artists/3eqjTLE0HfPfh78zjh6TqT',
#       'id': '3eqjTLE0HfPfh78zjh6TqT',
#       'name': 'Bruce Springsteen',
#       'type': 'artist',
#       'uri': 'spotify:artist:3eqjTLE0HfPfh78zjh6TqT'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 287360,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM19904335'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/556BL7XJ7PFXX8r3ozKYVa'},
#     'href': 'https://api.spotify.com/v1/tracks/556BL7XJ7PFXX8r3ozKYVa',
#     'id': '556BL7XJ7PFXX8r3ozKYVa',
#     'is_local': False,
#     'name': 'Thunder Road',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:556BL7XJ7PFXX8r3ozKYVa'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/51Blml2LZPmy7TTiAg47vQ'},
#        'href': 'https://api.spotify.com/v1/artists/51Blml2LZPmy7TTiAg47vQ',
#        'id': '51Blml2LZPmy7TTiAg47vQ',
#        'name': 'U2',
#        'type': 'artist',
#        'uri': 'spotify:artist:51Blml2LZPmy7TTiAg47vQ'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1U69hFsxaQxP6fquZmOmNH'},
#      'href': 'https://api.spotify.com/v1/albums/1U69hFsxaQxP6fquZmOmNH',
#      'id': '1U69hFsxaQxP6fquZmOmNH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b1bdbab41920011be3f223a7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b1bdbab41920011be3f223a7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b1bdbab41920011be3f223a7',
#        'width': 64}],
#      'name': 'Achtung Baby',
#      'release_date': '1991-11-18',
#      'release_date_precision': 'day',
#      'total_tracks': 26,
#      'type': 'album',
#      'uri': 'spotify:album:1U69hFsxaQxP6fquZmOmNH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/51Blml2LZPmy7TTiAg47vQ'},
#       'href': 'https://api.spotify.com/v1/artists/51Blml2LZPmy7TTiAg47vQ',
#       'id': '51Blml2LZPmy7TTiAg47vQ',
#       'name': 'U2',
#       'type': 'artist',
#       'uri': 'spotify:artist:51Blml2LZPmy7TTiAg47vQ'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 276186,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71106457'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3PY7bg1gPZIurkWnRguKUF'},
#     'href': 'https://api.spotify.com/v1/tracks/3PY7bg1gPZIurkWnRguKUF',
#     'id': '3PY7bg1gPZIurkWnRguKUF',
#     'is_local': False,
#     'name': 'One',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3PY7bg1gPZIurkWnRguKUF'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1nJvji2KIlWSseXRSlNYsC'},
#        'href': 'https://api.spotify.com/v1/artists/1nJvji2KIlWSseXRSlNYsC',
#        'id': '1nJvji2KIlWSseXRSlNYsC',
#        'name': 'The Velvet Underground',
#        'type': 'artist',
#        'uri': 'spotify:artist:1nJvji2KIlWSseXRSlNYsC'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0IwlY33zbBXN7zlS9DP2Cj'},
#        'href': 'https://api.spotify.com/v1/artists/0IwlY33zbBXN7zlS9DP2Cj',
#        'id': '0IwlY33zbBXN7zlS9DP2Cj',
#        'name': 'Nico',
#        'type': 'artist',
#        'uri': 'spotify:artist:0IwlY33zbBXN7zlS9DP2Cj'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3o7MFtKiZazZfZnW7dqwHA'},
#      'href': 'https://api.spotify.com/v1/albums/3o7MFtKiZazZfZnW7dqwHA',
#      'id': '3o7MFtKiZazZfZnW7dqwHA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ea94c1f22005932ec61d66b5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ea94c1f22005932ec61d66b5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ea94c1f22005932ec61d66b5',
#        'width': 64}],
#      'name': 'The Velvet Underground & Nico 45th Anniversary (Deluxe Edition)',
#      'release_date': '1967-03-12',
#      'release_date_precision': 'day',
#      'total_tracks': 31,
#      'type': 'album',
#      'uri': 'spotify:album:3o7MFtKiZazZfZnW7dqwHA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1nJvji2KIlWSseXRSlNYsC'},
#       'href': 'https://api.spotify.com/v1/artists/1nJvji2KIlWSseXRSlNYsC',
#       'id': '1nJvji2KIlWSseXRSlNYsC',
#       'name': 'The Velvet Underground',
#       'type': 'artist',
#       'uri': 'spotify:artist:1nJvji2KIlWSseXRSlNYsC'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0IwlY33zbBXN7zlS9DP2Cj'},
#       'href': 'https://api.spotify.com/v1/artists/0IwlY33zbBXN7zlS9DP2Cj',
#       'id': '0IwlY33zbBXN7zlS9DP2Cj',
#       'name': 'Nico',
#       'type': 'artist',
#       'uri': 'spotify:artist:0IwlY33zbBXN7zlS9DP2Cj'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 279520,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USPR36702760'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0zggnUZPh8kg69Jm7w7zZs'},
#     'href': 'https://api.spotify.com/v1/tracks/0zggnUZPh8kg69Jm7w7zZs',
#     'id': '0zggnUZPh8kg69Jm7w7zZs',
#     'is_local': False,
#     'name': "I'm Waiting For The Man - Album Version (Stereo)",
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0zggnUZPh8kg69Jm7w7zZs'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7guDJrEfX3qb6FEbdPA5qi'},
#        'href': 'https://api.spotify.com/v1/artists/7guDJrEfX3qb6FEbdPA5qi',
#        'id': '7guDJrEfX3qb6FEbdPA5qi',
#        'name': 'Stevie Wonder',
#        'type': 'artist',
#        'uri': 'spotify:artist:7guDJrEfX3qb6FEbdPA5qi'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0hF0PwB04hnXfYMiZWfJzy'},
#        'href': 'https://api.spotify.com/v1/artists/0hF0PwB04hnXfYMiZWfJzy',
#        'id': '0hF0PwB04hnXfYMiZWfJzy',
#        'name': 'Jimmy Ruffin',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hF0PwB04hnXfYMiZWfJzy'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6TKOZZDd5uV5KnyC5G4MUt'},
#        'href': 'https://api.spotify.com/v1/artists/6TKOZZDd5uV5KnyC5G4MUt',
#        'id': '6TKOZZDd5uV5KnyC5G4MUt',
#        'name': 'Smokey Robinson & The Miracles',
#        'type': 'artist',
#        'uri': 'spotify:artist:6TKOZZDd5uV5KnyC5G4MUt'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4LHtV0EkWCXspszwwhAarI'},
#      'href': 'https://api.spotify.com/v1/albums/4LHtV0EkWCXspszwwhAarI',
#      'id': '4LHtV0EkWCXspszwwhAarI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27366f014ab05962dd87d5c7b00',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0266f014ab05962dd87d5c7b00',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485166f014ab05962dd87d5c7b00',
#        'width': 64}],
#      'name': 'Stevie Wonder/ Jimmy Ruffin/ Smokey Robinson & The Miracles',
#      'release_date': '2003-07-28',
#      'release_date_precision': 'day',
#      'total_tracks': 54,
#      'type': 'album',
#      'uri': 'spotify:album:4LHtV0EkWCXspszwwhAarI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TKOZZDd5uV5KnyC5G4MUt'},
#       'href': 'https://api.spotify.com/v1/artists/6TKOZZDd5uV5KnyC5G4MUt',
#       'id': '6TKOZZDd5uV5KnyC5G4MUt',
#       'name': 'Smokey Robinson & The Miracles',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TKOZZDd5uV5KnyC5G4MUt'}],
#     'available_markets': [],
#     'disc_number': 3,
#     'duration_ms': 177733,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMO16500449'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/03uYIIUyvxk5kiCSltOTcZ'},
#     'href': 'https://api.spotify.com/v1/tracks/03uYIIUyvxk5kiCSltOTcZ',
#     'id': '03uYIIUyvxk5kiCSltOTcZ',
#     'is_local': False,
#     'name': 'The Tracks Of My Tears - Single Version / Mono',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:03uYIIUyvxk5kiCSltOTcZ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#        'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#        'id': '3WrFJ7ztbogyGnTHbHJFl2',
#        'name': 'The Beatles',
#        'type': 'artist',
#        'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/19K3IHYeVkUTjcBHGfbCOi'},
#      'href': 'https://api.spotify.com/v1/albums/19K3IHYeVkUTjcBHGfbCOi',
#      'id': '19K3IHYeVkUTjcBHGfbCOi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d967cd10468b9cf4e6bdfc7b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d967cd10468b9cf4e6bdfc7b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d967cd10468b9cf4e6bdfc7b',
#        'width': 64}],
#      'name': 'Help! (Remastered)',
#      'release_date': '1965-08-06',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:19K3IHYeVkUTjcBHGfbCOi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#       'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#       'id': '3WrFJ7ztbogyGnTHbHJFl2',
#       'name': 'The Beatles',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 125666,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE0601477'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1e0hllQ23AG0QGFgezgLOq'},
#     'href': 'https://api.spotify.com/v1/tracks/1e0hllQ23AG0QGFgezgLOq',
#     'id': '1e0hllQ23AG0QGFgezgLOq',
#     'is_local': False,
#     'name': 'Yesterday - Remastered',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:1e0hllQ23AG0QGFgezgLOq'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LcJLqbBmaGUft1e9Mm8HV'},
#        'href': 'https://api.spotify.com/v1/artists/0LcJLqbBmaGUft1e9Mm8HV',
#        'id': '0LcJLqbBmaGUft1e9Mm8HV',
#        'name': 'ABBA',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LcJLqbBmaGUft1e9Mm8HV'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/79ZX48114T8NH36MnOTtl7'},
#      'href': 'https://api.spotify.com/v1/albums/79ZX48114T8NH36MnOTtl7',
#      'id': '79ZX48114T8NH36MnOTtl7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739aa209383c254c9e23e7f909',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029aa209383c254c9e23e7f909',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519aa209383c254c9e23e7f909',
#        'width': 64}],
#      'name': 'Arrival',
#      'release_date': '1976-10-11',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:79ZX48114T8NH36MnOTtl7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LcJLqbBmaGUft1e9Mm8HV'},
#       'href': 'https://api.spotify.com/v1/artists/0LcJLqbBmaGUft1e9Mm8HV',
#       'id': '0LcJLqbBmaGUft1e9Mm8HV',
#       'name': 'ABBA',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LcJLqbBmaGUft1e9Mm8HV'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 230400,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SEAYD7601020'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/01iyCAUm8EvOFqVWYJ3dVX'},
#     'href': 'https://api.spotify.com/v1/tracks/01iyCAUm8EvOFqVWYJ3dVX',
#     'id': '01iyCAUm8EvOFqVWYJ3dVX',
#     'is_local': False,
#     'name': 'Dancing Queen',
#     'popularity': 1,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:01iyCAUm8EvOFqVWYJ3dVX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1p0t3JtUTayV2wb1RGN9mO'},
#        'href': 'https://api.spotify.com/v1/artists/1p0t3JtUTayV2wb1RGN9mO',
#        'id': '1p0t3JtUTayV2wb1RGN9mO',
#        'name': 'Eddie Cochran',
#        'type': 'artist',
#        'uri': 'spotify:artist:1p0t3JtUTayV2wb1RGN9mO'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/25TCdjTn54TAHVulRohu4G'},
#      'href': 'https://api.spotify.com/v1/albums/25TCdjTn54TAHVulRohu4G',
#      'id': '25TCdjTn54TAHVulRohu4G',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739faa93ae6fbf703b1aa1e3df',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029faa93ae6fbf703b1aa1e3df',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519faa93ae6fbf703b1aa1e3df',
#        'width': 64}],
#      'name': 'The Very Best Of',
#      'release_date': '1990',
#      'release_date_precision': 'year',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:25TCdjTn54TAHVulRohu4G'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1p0t3JtUTayV2wb1RGN9mO'},
#       'href': 'https://api.spotify.com/v1/artists/1p0t3JtUTayV2wb1RGN9mO',
#       'id': '1p0t3JtUTayV2wb1RGN9mO',
#       'name': 'Eddie Cochran',
#       'type': 'artist',
#       'uri': 'spotify:artist:1p0t3JtUTayV2wb1RGN9mO'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 120000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEM38800220'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2wwRSaZgshcHSvGzWryUIi'},
#     'href': 'https://api.spotify.com/v1/tracks/2wwRSaZgshcHSvGzWryUIi',
#     'id': '2wwRSaZgshcHSvGzWryUIi',
#     'is_local': False,
#     'name': 'Summertime Blues',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:2wwRSaZgshcHSvGzWryUIi'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3yY2gUcIsjMr8hjo51PoJ8'},
#        'href': 'https://api.spotify.com/v1/artists/3yY2gUcIsjMr8hjo51PoJ8',
#        'id': '3yY2gUcIsjMr8hjo51PoJ8',
#        'name': 'The Smiths',
#        'type': 'artist',
#        'uri': 'spotify:artist:3yY2gUcIsjMr8hjo51PoJ8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6cI1XoZsOhkyrCwtuI70CN'},
#      'href': 'https://api.spotify.com/v1/albums/6cI1XoZsOhkyrCwtuI70CN',
#      'id': '6cI1XoZsOhkyrCwtuI70CN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a09b231129ab1cb1a6efc57f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a09b231129ab1cb1a6efc57f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a09b231129ab1cb1a6efc57f',
#        'width': 64}],
#      'name': 'The Smiths',
#      'release_date': '1984-02-20',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6cI1XoZsOhkyrCwtuI70CN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3yY2gUcIsjMr8hjo51PoJ8'},
#       'href': 'https://api.spotify.com/v1/artists/3yY2gUcIsjMr8hjo51PoJ8',
#       'id': '3yY2gUcIsjMr8hjo51PoJ8',
#       'name': 'The Smiths',
#       'type': 'artist',
#       'uri': 'spotify:artist:3yY2gUcIsjMr8hjo51PoJ8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 162920,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCRL1100240'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1FvDJ9KGxcqwv1utyPL3JZ'},
#     'href': 'https://api.spotify.com/v1/tracks/1FvDJ9KGxcqwv1utyPL3JZ',
#     'id': '1FvDJ9KGxcqwv1utyPL3JZ',
#     'is_local': False,
#     'name': 'This Charming Man - 2011 Remaster',
#     'popularity': 75,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ed476d2bac701fbc5ddb85f2ee7c5b556158b462?cid=da382d4fb57948c198390a9508c0f02c',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:1FvDJ9KGxcqwv1utyPL3JZ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/70cZCfQmUAaiyMA30CWgGU'},
#      'href': 'https://api.spotify.com/v1/albums/70cZCfQmUAaiyMA30CWgGU',
#      'id': '70cZCfQmUAaiyMA30CWgGU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bb7d3d7a002467b49f48ee13',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bb7d3d7a002467b49f48ee13',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bb7d3d7a002467b49f48ee13',
#        'width': 64}],
#      'name': 'The Roots of Nick Cave',
#      'release_date': '2009-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:70cZCfQmUAaiyMA30CWgGU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5hIClg6noTaCzMu2s5wp4f'},
#       'href': 'https://api.spotify.com/v1/artists/5hIClg6noTaCzMu2s5wp4f',
#       'id': '5hIClg6noTaCzMu2s5wp4f',
#       'name': 'Carl Perkins',
#       'type': 'artist',
#       'uri': 'spotify:artist:5hIClg6noTaCzMu2s5wp4f'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 137053,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCQV0900041'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1EJovYCU4hrSNlnExSqGnK'},
#     'href': 'https://api.spotify.com/v1/tracks/1EJovYCU4hrSNlnExSqGnK',
#     'id': '1EJovYCU4hrSNlnExSqGnK',
#     'is_local': False,
#     'name': 'Blue Suede Shoes',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1EJovYCU4hrSNlnExSqGnK'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Xf8oDAJYd2D0k3NLI19OV'},
#        'href': 'https://api.spotify.com/v1/artists/0Xf8oDAJYd2D0k3NLI19OV',
#        'id': '0Xf8oDAJYd2D0k3NLI19OV',
#        'name': 'CHIC',
#        'type': 'artist',
#        'uri': 'spotify:artist:0Xf8oDAJYd2D0k3NLI19OV'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1UFBJkKiBe3Lzjr307UhuU'},
#      'href': 'https://api.spotify.com/v1/albums/1UFBJkKiBe3Lzjr307UhuU',
#      'id': '1UFBJkKiBe3Lzjr307UhuU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d237a27633d01d25fdaa1c33',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d237a27633d01d25fdaa1c33',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d237a27633d01d25fdaa1c33',
#        'width': 64}],
#      'name': 'Risqué',
#      'release_date': '1979-07-30',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:1UFBJkKiBe3Lzjr307UhuU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Xf8oDAJYd2D0k3NLI19OV'},
#       'href': 'https://api.spotify.com/v1/artists/0Xf8oDAJYd2D0k3NLI19OV',
#       'id': '0Xf8oDAJYd2D0k3NLI19OV',
#       'name': 'CHIC',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Xf8oDAJYd2D0k3NLI19OV'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 495400,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT20001676'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0G3fbPbE1vGeABDEZF0jeG'},
#     'href': 'https://api.spotify.com/v1/tracks/0G3fbPbE1vGeABDEZF0jeG',
#     'id': '0G3fbPbE1vGeABDEZF0jeG',
#     'is_local': False,
#     'name': 'Good Times',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b54575c7efba12cd93c8c7ab8e0cbc9021543cdd?cid=da382d4fb57948c198390a9508c0f02c',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0G3fbPbE1vGeABDEZF0jeG'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2h93pZq0e7k5yf4dywlkpM'},
#        'href': 'https://api.spotify.com/v1/artists/2h93pZq0e7k5yf4dywlkpM',
#        'id': '2h93pZq0e7k5yf4dywlkpM',
#        'name': 'Frank Ocean',
#        'type': 'artist',
#        'uri': 'spotify:artist:2h93pZq0e7k5yf4dywlkpM'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/623Ef2ZEB3Njklix4PC0Rs'},
#      'href': 'https://api.spotify.com/v1/albums/623Ef2ZEB3Njklix4PC0Rs',
#      'id': '623Ef2ZEB3Njklix4PC0Rs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f11f1c4ad183b7fa625f8534',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f11f1c4ad183b7fa625f8534',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f11f1c4ad183b7fa625f8534',
#        'width': 64}],
#      'name': 'channel ORANGE (Explicit Version)',
#      'release_date': '2012-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:623Ef2ZEB3Njklix4PC0Rs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2h93pZq0e7k5yf4dywlkpM'},
#       'href': 'https://api.spotify.com/v1/artists/2h93pZq0e7k5yf4dywlkpM',
#       'id': '2h93pZq0e7k5yf4dywlkpM',
#       'name': 'Frank Ocean',
#       'type': 'artist',
#       'uri': 'spotify:artist:2h93pZq0e7k5yf4dywlkpM'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 592920,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71207185'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0rbK15g3UsDTVy1EuwgKYz'},
#     'href': 'https://api.spotify.com/v1/tracks/0rbK15g3UsDTVy1EuwgKYz',
#     'id': '0rbK15g3UsDTVy1EuwgKYz',
#     'is_local': False,
#     'name': 'Pyramids',
#     'popularity': 14,
#     'preview_url': None,
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:0rbK15g3UsDTVy1EuwgKYz'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1D9fjF0NsNR1LvtdFOwaZM'},
#      'href': 'https://api.spotify.com/v1/albums/1D9fjF0NsNR1LvtdFOwaZM',
#      'id': '1D9fjF0NsNR1LvtdFOwaZM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d2385d8c43caaa617de904cf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d2385d8c43caaa617de904cf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d2385d8c43caaa617de904cf',
#        'width': 64}],
#      'name': 'Motown Essentials',
#      'release_date': '2009-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 124,
#      'type': 'album',
#      'uri': 'spotify:album:1D9fjF0NsNR1LvtdFOwaZM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3RwQ26hR2tJtA8F9p2n7jG'},
#       'href': 'https://api.spotify.com/v1/artists/3RwQ26hR2tJtA8F9p2n7jG',
#       'id': '3RwQ26hR2tJtA8F9p2n7jG',
#       'name': 'The Temptations',
#       'type': 'artist',
#       'uri': 'spotify:artist:3RwQ26hR2tJtA8F9p2n7jG'}],
#     'available_markets': [],
#     'disc_number': 7,
#     'duration_ms': 175813,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMO10111043'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4jfmXzc1eCFIVvIVAkH4Fo'},
#     'href': 'https://api.spotify.com/v1/tracks/4jfmXzc1eCFIVvIVAkH4Fo',
#     'id': '4jfmXzc1eCFIVvIVAkH4Fo',
#     'is_local': False,
#     'name': 'My Girl - Single Version/Mono',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4jfmXzc1eCFIVvIVAkH4Fo'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22bE4uQ6baNwSHPVcDxLCe'},
#        'href': 'https://api.spotify.com/v1/artists/22bE4uQ6baNwSHPVcDxLCe',
#        'id': '22bE4uQ6baNwSHPVcDxLCe',
#        'name': 'The Rolling Stones',
#        'type': 'artist',
#        'uri': 'spotify:artist:22bE4uQ6baNwSHPVcDxLCe'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2EXY5L6GbdSrRR3mo5Bes5'},
#      'href': 'https://api.spotify.com/v1/albums/2EXY5L6GbdSrRR3mo5Bes5',
#      'id': '2EXY5L6GbdSrRR3mo5Bes5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273650fd478e285316014934a77',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02650fd478e285316014934a77',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851650fd478e285316014934a77',
#        'width': 64}],
#      'name': 'Singles 1965-1967',
#      'release_date': '2004-07-12',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:2EXY5L6GbdSrRR3mo5Bes5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22bE4uQ6baNwSHPVcDxLCe'},
#       'href': 'https://api.spotify.com/v1/artists/22bE4uQ6baNwSHPVcDxLCe',
#       'id': '22bE4uQ6baNwSHPVcDxLCe',
#       'name': 'The Rolling Stones',
#       'type': 'artist',
#       'uri': 'spotify:artist:22bE4uQ6baNwSHPVcDxLCe'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 224133,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA176610020'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/78Az0Z1vNJgqv9QSB0ULLV'},
#     'href': 'https://api.spotify.com/v1/tracks/78Az0Z1vNJgqv9QSB0ULLV',
#     'id': '78Az0Z1vNJgqv9QSB0ULLV',
#     'is_local': False,
#     'name': 'Paint It Black',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:78Az0Z1vNJgqv9QSB0ULLV'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
# ...
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 168640,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSE60070036'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6bXsnQ8laHa6cVK1JO9dmg'},
#     'href': 'https://api.spotify.com/v1/tracks/6bXsnQ8laHa6cVK1JO9dmg',
#     'id': '6bXsnQ8laHa6cVK1JO9dmg',
#     'is_local': False,
#     'name': 'Folsom Prison Blues',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/477db31e90ef625004590f31b28bba9224eeeb4e?cid=da382d4fb57948c198390a9508c0f02c',
#     'track': True,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:6bXsnQ8laHa6cVK1JO9dmg'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2EaR3hamoenG9rDuVn8j'},
#        'href': 'https://api.spotify.com/v1/artists/5a2EaR3hamoenG9rDuVn8j',
#        'id': '5a2EaR3hamoenG9rDuVn8j',
#        'name': 'Prince',
#        'type': 'artist',
#        'uri': 'spotify:artist:5a2EaR3hamoenG9rDuVn8j'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5oQClEU6YXiVoaz4ZTmOOO'},
#      'href': 'https://api.spotify.com/v1/albums/5oQClEU6YXiVoaz4ZTmOOO',
#      'id': '5oQClEU6YXiVoaz4ZTmOOO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a64a256c50d2cc6e2d3917bb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a64a256c50d2cc6e2d3917bb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a64a256c50d2cc6e2d3917bb',
#        'width': 64}],
#      'name': 'The Very Best of Prince',
#      'release_date': '2001-07-30',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:5oQClEU6YXiVoaz4ZTmOOO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2EaR3hamoenG9rDuVn8j'},
#       'href': 'https://api.spotify.com/v1/artists/5a2EaR3hamoenG9rDuVn8j',
#       'id': '5a2EaR3hamoenG9rDuVn8j',
#       'name': 'Prince',
#       'type': 'artist',
#       'uri': 'spotify:artist:5a2EaR3hamoenG9rDuVn8j'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 223506,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB19901187'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5lHWWhuRtSBKfH2xS6YAUD'},
#     'href': 'https://api.spotify.com/v1/tracks/5lHWWhuRtSBKfH2xS6YAUD',
#     'id': '5lHWWhuRtSBKfH2xS6YAUD',
#     'is_local': False,
#     'name': "Sign 'O' the Times - Single Version",
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0c8a4c7bf85f350fe604a34ea8f4d65823df7b95?cid=da382d4fb57948c198390a9508c0f02c',
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:5lHWWhuRtSBKfH2xS6YAUD'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-29T15:02:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/acclaimedmusic'},
#     'href': 'https://api.spotify.com/v1/users/acclaimedmusic',
#     'id': 'acclaimedmusic',
#     'type': 'user',
#     'uri': 'spotify:user:acclaimedmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0S0KGZnfBGSIssfF54WSJh'},
#      'href': 'https://api.spotify.com/v1/albums/0S0KGZnfBGSIssfF54WSJh',
#      'id': '0S0KGZnfBGSIssfF54WSJh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27350a3147b4edd7701a876c6ce',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0250a3147b4edd7701a876c6ce',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485150a3147b4edd7701a876c6ce',
#        'width': 64}],
#      'name': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#      'release_date': '2019-03-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0S0KGZnfBGSIssfF54WSJh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 194087,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71900764'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Fxmhks0bxGSBdJ92vM42m'},
#     'href': 'https://api.spotify.com/v1/tracks/2Fxmhks0bxGSBdJ92vM42m',
#     'id': '2Fxmhks0bxGSBdJ92vM42m',
#     'is_local': False,
#     'name': 'bad guy',
#     'popularity': 84,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2Fxmhks0bxGSBdJ92vM42m'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/1G8IpkZKobrIlXcVPoSIuf/tracks?offset=200&limit=100&additional_types=track',
#  'offset': 100,
#  'previous': 'https://api.spotify.com/v1/playlists/1G8IpkZKobrIlXcVPoSIuf/tracks?offset=0&limit=100&additional_types=track',
#  'total': 10000}

# %%
#function to extract all songs from a large playlist

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3))
    return tracks

# %%
all_tracks = get_playlist_tracks("1G8IpkZKobrIlXcVPoSIuf")
len(all_tracks)
#this now holds all 10,000 songs and their artists
#need to make it into a dataframe, once we've pared it down!
# Out:
# 10000

# %%
#all_tracks holds all info for all 10,000 songs, it's big list of dictionary
#it's not fit to be a dataframe yet

# %%
#we ONLY need artist, name of song, and URI for the database

# %% [markdown]
# Getting the artist name and song name

# %%
#getting to artist name
all_tracks[0]['track']['artists'][0]['name']
# Out:
# 'Bob Dylan'

# %%
#getting to song name
all_tracks[0]['track']['name']
# Out:
# 'Like a Rolling Stone'

# %% [markdown]
# ### Getting the artist, song name, and URI from each song of my playlist

# %%
all_tracks[0]['track']['uri']
# Out:
# 'spotify:track:3AhXZa8sUQht0UEdBJgpGc'

# %%
song_uri = all_tracks[0]['track']['uri']
#song_uri = all_tracks['items'][0]['track']['uri']
song_uri
# Out:
# 'spotify:track:3AhXZa8sUQht0UEdBJgpGc'

# %%
sp.audio_features(song_uri)
# Out:
# [{'danceability': 0.482,
#   'energy': 0.721,
#   'key': 0,
#   'loudness': -6.839,
#   'mode': 1,
#   'speechiness': 0.0321,
#   'acousticness': 0.731,
#   'instrumentalness': 0,
#   'liveness': 0.189,
#   'valence': 0.557,
#   'tempo': 95.263,
#   'type': 'audio_features',
#   'id': '3AhXZa8sUQht0UEdBJgpGc',
#   'uri': 'spotify:track:3AhXZa8sUQht0UEdBJgpGc',
#   'track_href': 'https://api.spotify.com/v1/tracks/3AhXZa8sUQht0UEdBJgpGc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3AhXZa8sUQht0UEdBJgpGc',
#   'duration_ms': 369600,
#   'time_signature': 4}]

# %%
#creating lists to hold song, artist, uri
song_name = []   
artist_name = []
track_uri = []

# %%
#use a "for" loop to get the audio features, artists, and song names of all 10,000 songs in the playlist and
#put them inside the lists created above, making sure to ignore the Nans

# %%
for i in range(len(all_tracks)):
    try:
        song = all_tracks[i]['track']['name']
        artist = all_tracks[i]["track"]["album"]['artists'][0]['name']
        uri = all_tracks[i]['track']['uri']
        
        artist_name.append(artist)
        song_name.append(song)
        track_uri.append(uri)
    except:
        artist_name.append('none')
        song_name.append('none')
        track_uri.append('none')

# %%
spotify_df=pd.DataFrame(
    {'song': song_name,
     'artist': artist_name,
     'uri': track_uri
    })

# %%
spotify_df.head(5)
# Out:
#                              song          artist  \
# 0            Like a Rolling Stone       Bob Dylan
# 1         Smells Like Teen Spirit         Nirvana
# 2  A Day In The Life - Remastered     The Beatles
# 3          Good Vibrations (Mono)  The Beach Boys
# 4                  Johnny B Goode     Chuck Berry
#
#                                     uri
# 0  spotify:track:3AhXZa8sUQht0UEdBJgpGc
# 1  spotify:track:3oTlkzk1OtrhH8wBAduVEi
# 2  spotify:track:3ZFBeIyP41HhnALjxWy1pR
# 3  spotify:track:5Qt4Cc66g24QWwGP3YYV9y
# 4  spotify:track:7MH2ZclofPlTrZOkPzZKhK

# %%
spotify_df.song.value_counts()
#can see there are 53 "nones"
# Out:
# none                    53
# Summertime               6
# Girlfriend               4
# Crazy                    4
# Fire                     4
#                         ..
# Young Adult Friction     1
# The Pusher               1
# If You Leave Me Now      1
# Worried Life Blues       1
# Come Dancing             1
# Name: song, Length: 9641, dtype: int64

# %%
spotify_df = spotify_df[spotify_df.song != 'none'] # removing all the rows that have 'none'

# %%
spotify_df.shape
# Out:
# (9947, 3)

# %%
# since we removed all the values that had 'none' we need to reset index

spotify_df.reset_index(inplace=True)

# %%
spotify_df.drop('index', axis=1, inplace=True) # drop extra index column created after reset_index

# %%
spotify_df.head()
# Out:
#                              song          artist  \
# 0            Like a Rolling Stone       Bob Dylan
# 1         Smells Like Teen Spirit         Nirvana
# 2  A Day In The Life - Remastered     The Beatles
# 3          Good Vibrations (Mono)  The Beach Boys
# 4                  Johnny B Goode     Chuck Berry
#
#                                     uri
# 0  spotify:track:3AhXZa8sUQht0UEdBJgpGc
# 1  spotify:track:3oTlkzk1OtrhH8wBAduVEi
# 2  spotify:track:3ZFBeIyP41HhnALjxWy1pR
# 3  spotify:track:5Qt4Cc66g24QWwGP3YYV9y
# 4  spotify:track:7MH2ZclofPlTrZOkPzZKhK

# %% [markdown]
# ### Getting the audio features

# %%
#thanks to Asha and Erin for their help with this part!!

# collecting all the audiofeatures in a list
# commenting this code to prevent running the spotify api

# audio_features = []
# counter = 0  # setting a counter so that we can stop the code for 10 seconds when counter is 100

# for item in track_uri:
#     features = sp.audio_features(item)
#     audio_features.append(features)

#     counter = counter + 1
    
#     if counter % 100 == 0:
#         sleep(10)

# %%
sp.audio_features(track_uri[1])
# Out:
# [{'danceability': 0.485,
#   'energy': 0.863,
#   'key': 1,
#   'loudness': -9.027,
#   'mode': 1,
#   'speechiness': 0.0495,
#   'acousticness': 1.22e-05,
#   'instrumentalness': 0.0162,
#   'liveness': 0.138,
#   'valence': 0.767,
#   'tempo': 116.835,
#   'type': 'audio_features',
#   'id': '3oTlkzk1OtrhH8wBAduVEi',
#   'uri': 'spotify:track:3oTlkzk1OtrhH8wBAduVEi',
#   'track_href': 'https://api.spotify.com/v1/tracks/3oTlkzk1OtrhH8wBAduVEi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3oTlkzk1OtrhH8wBAduVEi',
#   'duration_ms': 300977,
#   'time_signature': 4}]

# %%
# collecting all the audiofeatures in a list
# commenting this code to prevent running the spotify api

#audio_features = []
#counter = 0  # setting a counter so that we can stop the code for 10 seconds when counter is 100

#for item in track_uri:
#     features = sp.audio_features(item)
#     audio_features.append(features)

 #    counter = counter + 1
    
#     if counter % 100 == 0:
#         sleep(10)

# %%
[None] in audio_features # some of the audiofeatures have [None] because there was no trackuri
# Out:
# True

# %%
#creating lists to hold each audio feature

danceability = []
energy = []
loudness = []
speechiness = []
acousticness = []
instrumentalness = []
liveness = []
valence = []
tempo = []

# %%
for i in range(len(audio_features)):
    #making sure we only run the for loop when it is not [None]
    if audio_features[i] != [None]:  
        danceability.append(audio_features[i][0]['danceability'])
        energy.append(audio_features[i][0]['energy'])
        loudness.append(audio_features[i][0]['loudness'])
        speechiness.append(audio_features[i][0]['speechiness'])
        acousticness.append(audio_features[i][0]['acousticness'])
        instrumentalness.append(audio_features[i][0]['instrumentalness'])
        liveness.append(audio_features[i][0]['liveness'])
        valence.append(audio_features[i][0]['valence'])
        tempo.append(audio_features[i][0]['tempo'])

# %%
spotify_af = pd.DataFrame({'danceability' : danceability,
                          'energy': energy,
                          'loudness': loudness,
                          'speechiness': speechiness,
                           'acousticness': acousticness,
                           'instrumentalness': instrumentalness,
                           'liveness': liveness,
                           'valence': valence,
                           'tempo': tempo
                          })

# %%
spotify_af
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.482   0.721    -6.839       0.0321      0.731000
# 1            0.485   0.863    -9.027       0.0495      0.000012
# 2            0.364   0.457   -14.162       0.0675      0.290000
# 3            0.398   0.413   -10.934       0.0388      0.082200
# 4            0.518   0.756   -10.851       0.0915      0.735000
# ...            ...     ...       ...          ...           ...
# 9942         0.332   0.707   -12.698       0.0361      0.000012
# 9943         0.464   0.749    -8.564       0.4800      0.224000
# 9944         0.694   0.710    -9.793       0.3400      0.527000
# 9945         0.332   0.800    -9.746       0.0326      0.000368
# 9946         0.499   0.763   -11.617       0.0704      0.244000
#
#       instrumentalness  liveness  valence    tempo
# 0             0.000000    0.1890    0.557   95.263
# 1             0.016200    0.1380    0.767  116.835
# 2             0.000106    0.9220    0.175  163.219
# 3             0.000025    0.0891    0.331  133.574
# 4             0.000062    0.3170    0.968  166.429
# ...                ...       ...      ...      ...
# 9942          0.006120    0.1100    0.652  144.815
# 9943          0.000046    0.3510    0.879  181.121
# 9944          0.001350    0.0697    0.415  119.964
# 9945          0.001600    0.0850    0.832  149.240
# 9946          0.000014    0.0828    0.895  152.677
#
# [9947 rows x 9 columns]

# %%
spotify_final = pd.concat([spotify_df, spotify_af], axis=1)

# %%
#afterwards, create a dataframe with all the features (and songs and artists?) and save in local drive?
#so don't need to re-do this whole process again if need to restart kernel

# %%
spotify_final.head()
# Out:
#                              song          artist  \
# 0            Like a Rolling Stone       Bob Dylan
# 1         Smells Like Teen Spirit         Nirvana
# 2  A Day In The Life - Remastered     The Beatles
# 3          Good Vibrations (Mono)  The Beach Boys
# 4                  Johnny B Goode     Chuck Berry
#
#                                     uri  danceability  energy  loudness  \
# 0  spotify:track:3AhXZa8sUQht0UEdBJgpGc         0.482   0.721    -6.839
# 1  spotify:track:3oTlkzk1OtrhH8wBAduVEi         0.485   0.863    -9.027
# 2  spotify:track:3ZFBeIyP41HhnALjxWy1pR         0.364   0.457   -14.162
# 3  spotify:track:5Qt4Cc66g24QWwGP3YYV9y         0.398   0.413   -10.934
# 4  spotify:track:7MH2ZclofPlTrZOkPzZKhK         0.518   0.756   -10.851
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 0       0.0321      0.731000          0.000000    0.1890    0.557   95.263
# 1       0.0495      0.000012          0.016200    0.1380    0.767  116.835
# 2       0.0675      0.290000          0.000106    0.9220    0.175  163.219
# 3       0.0388      0.082200          0.000025    0.0891    0.331  133.574
# 4       0.0915      0.735000          0.000062    0.3170    0.968  166.429

# %%
spotify_final.to_csv('spotify_final.csv')

# %% [markdown]
# # Unsupervised Machine Learning Lab | Clustering
#
# It's the moment to perform clustering on the songs you collected.
#
# Remember that the ultimate goal of this little project is to improve the recommendations of artists.
#
# Clustering the songs will allow the recommendation system to limit the scope of the recommendations to only songs
#
# that belong to the same cluster - songs with similar audio features.

# %%
from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
#import the dataset

spotify_cluster = pd.read_csv('spotify_final.csv')
spotify_cluster.describe().T
#spotify_cluster
# Out:
#                    count         mean          std       min          25%  \
# Unnamed: 0        9947.0  4973.000000  2871.595898   0.00000  2486.500000
# danceability      9947.0     0.565502     0.166720   0.06920     0.451000
# energy            9947.0     0.616762     0.233718   0.00002     0.450500
# loudness          9947.0    -9.201222     3.860798 -60.00000   -11.578000
# speechiness       9947.0     0.071010     0.074826   0.02260     0.033500
# acousticness      9947.0     0.307052     0.324786   0.00000     0.023400
# instrumentalness  9947.0     0.106172     0.239800   0.00000     0.000002
# liveness          9947.0     0.189563     0.153860   0.00829     0.091700
# valence           9947.0     0.576935     0.246170   0.03270     0.383500
# tempo             9947.0   121.333657    27.959629  37.11400   100.588500
#
#                           50%        75%       max
# Unnamed: 0        4973.000000  7459.5000  9946.000
# danceability         0.568000     0.6850     0.988
# energy               0.651000     0.8090     0.998
# loudness            -8.656000    -6.3230     1.342
# speechiness          0.043300     0.0702     0.934
# acousticness         0.167000     0.5635     0.996
# instrumentalness     0.000315     0.0297     0.993
# liveness             0.129000     0.2460     0.993
# valence              0.592000     0.7800     0.988
# tempo              120.046000   137.3295   217.591

# %%
#del spotify_cluster["Unnamed: 0"]  #can only run this once, once it's been deleted
spotify_cluster
# Out:
#                                 song                  artist  \
# 0               Like a Rolling Stone               Bob Dylan
# 1            Smells Like Teen Spirit                 Nirvana
# 2     A Day In The Life - Remastered             The Beatles
# 3             Good Vibrations (Mono)          The Beach Boys
# 4                     Johnny B Goode             Chuck Berry
# ...                              ...                     ...
# 9942                 Into The Valley                   Skids
# 9943              Tonight's Da Night                  Redman
# 9944                        Figure 8               FKA twigs
# 9945                   Like An Angel  The Mighty Lemon Drops
# 9946                    Come Dancing               The Kinks
#
#                                        uri  danceability  energy  loudness  \
# 0     spotify:track:3AhXZa8sUQht0UEdBJgpGc         0.482   0.721    -6.839
# 1     spotify:track:3oTlkzk1OtrhH8wBAduVEi         0.485   0.863    -9.027
# 2     spotify:track:3ZFBeIyP41HhnALjxWy1pR         0.364   0.457   -14.162
# 3     spotify:track:5Qt4Cc66g24QWwGP3YYV9y         0.398   0.413   -10.934
# 4     spotify:track:7MH2ZclofPlTrZOkPzZKhK         0.518   0.756   -10.851
# ...                                    ...           ...     ...       ...
# 9942  spotify:track:2QSD3K3b3BJ8DPhGhQfDPW         0.332   0.707   -12.698
# 9943  spotify:track:49XnDVsYOHgV4gFZeCojKj         0.464   0.749    -8.564
# 9944  spotify:track:5Y9IIH8Xmo1nuk0gfFjc4Q         0.694   0.710    -9.793
# 9945  spotify:track:0ya0JYEFoXNviB8RMeHDtW         0.332   0.800    -9.746
# 9946  spotify:track:32y1kRg6IF3f6jpkHxzFoK         0.499   0.763   -11.617
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 0          0.0321      0.731000          0.000000    0.1890    0.557   95.263
# 1          0.0495      0.000012          0.016200    0.1380    0.767  116.835
# 2          0.0675      0.290000          0.000106    0.9220    0.175  163.219
# 3          0.0388      0.082200          0.000025    0.0891    0.331  133.574
# 4          0.0915      0.735000          0.000062    0.3170    0.968  166.429
# ...           ...           ...               ...       ...      ...      ...
# 9942       0.0361      0.000012          0.006120    0.1100    0.652  144.815
# 9943       0.4800      0.224000          0.000046    0.3510    0.879  181.121
# 9944       0.3400      0.527000          0.001350    0.0697    0.415  119.964
# 9945       0.0326      0.000368          0.001600    0.0850    0.832  149.240
# 9946       0.0704      0.244000          0.000014    0.0828    0.895  152.677
#
# [9947 rows x 12 columns]

# %%
spotify_cluster.describe().T
# Out:
#                    count        mean        std       min         25%  \
# danceability      9947.0    0.565502   0.166720   0.06920    0.451000
# energy            9947.0    0.616762   0.233718   0.00002    0.450500
# loudness          9947.0   -9.201222   3.860798 -60.00000  -11.578000
# speechiness       9947.0    0.071010   0.074826   0.02260    0.033500
# acousticness      9947.0    0.307052   0.324786   0.00000    0.023400
# instrumentalness  9947.0    0.106172   0.239800   0.00000    0.000002
# liveness          9947.0    0.189563   0.153860   0.00829    0.091700
# valence           9947.0    0.576935   0.246170   0.03270    0.383500
# tempo             9947.0  121.333657  27.959629  37.11400  100.588500
#
#                          50%       75%      max
# danceability        0.568000    0.6850    0.988
# energy              0.651000    0.8090    0.998
# loudness           -8.656000   -6.3230    1.342
# speechiness         0.043300    0.0702    0.934
# acousticness        0.167000    0.5635    0.996
# instrumentalness    0.000315    0.0297    0.993
# liveness            0.129000    0.2460    0.993
# valence             0.592000    0.7800    0.988
# tempo             120.046000  137.3295  217.591

# %%
#make dataframe with audiofeatures only, because the rest are categorical

audio_features = spotify_cluster[['danceability', 'energy', 'loudness', 'speechiness',
                      'acousticness', 'instrumentalness', 'liveness', 
                      'valence', 'tempo']]
audio_features
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.482   0.721    -6.839       0.0321      0.731000
# 1            0.485   0.863    -9.027       0.0495      0.000012
# 2            0.364   0.457   -14.162       0.0675      0.290000
# 3            0.398   0.413   -10.934       0.0388      0.082200
# 4            0.518   0.756   -10.851       0.0915      0.735000
# ...            ...     ...       ...          ...           ...
# 9942         0.332   0.707   -12.698       0.0361      0.000012
# 9943         0.464   0.749    -8.564       0.4800      0.224000
# 9944         0.694   0.710    -9.793       0.3400      0.527000
# 9945         0.332   0.800    -9.746       0.0326      0.000368
# 9946         0.499   0.763   -11.617       0.0704      0.244000
#
#       instrumentalness  liveness  valence    tempo
# 0             0.000000    0.1890    0.557   95.263
# 1             0.016200    0.1380    0.767  116.835
# 2             0.000106    0.9220    0.175  163.219
# 3             0.000025    0.0891    0.331  133.574
# 4             0.000062    0.3170    0.968  166.429
# ...                ...       ...      ...      ...
# 9942          0.006120    0.1100    0.652  144.815
# 9943          0.000046    0.3510    0.879  181.121
# 9944          0.001350    0.0697    0.415  119.964
# 9945          0.001600    0.0850    0.832  149.240
# 9946          0.000014    0.0828    0.895  152.677
#
# [9947 rows x 9 columns]

# %%
# The scale of "tempo" is much higher than the scale of many other variables!
# K-Means is a distance based algorithm: we need to scale / normalize:

#This ned to be saved in pickle
X_prep = StandardScaler().fit_transform(audio_features)

scaler = StandardScaler().fit(audio_features)


# Now, all features will have the same weight.
pd.DataFrame(X_prep,columns=audio_features.columns).head()

#here we have using standardscaler, but we should also try it with min/max scaler to see results
# Out:
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -0.500877  0.446024  0.611879    -0.520037      1.305379
# 1     -0.482882  1.053625  0.045128    -0.287486     -0.945408
# 2     -1.208686 -0.683601 -1.284975    -0.046916     -0.052505
# 3     -1.004741 -0.871872 -0.448836    -0.430491     -0.692343
# 4     -0.284935  0.595785 -0.427337     0.273845      1.317696
#
#    instrumentalness  liveness   valence     tempo
# 0         -0.442774 -0.003658 -0.080983 -0.932486
# 1         -0.375215 -0.335144  0.772129 -0.160906
# 2         -0.442332  4.760650 -1.632833  1.498140
# 3         -0.442668 -0.652981 -0.999093  0.437808
# 4         -0.442516  0.828309  1.588678  1.612955

# %%
import pickle

#saving the scaler for song reccomender
pickle.dump(scaler, open('scaler.pkl', 'wb'))

# %% [markdown]
# ### Choosing K

# %%
#import numpy as np    #very similar to doing K nearest neighbors function

K = range(3, 10) #how choose this range?
inertia = [] 

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)
    
#import matplotlib.pyplot as plt
#%matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
#so we've built 7 models here (with K ranging between 2 and 9)

#doesn't yield a very clear optimal k, looks at 5 or 6
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
#now test to determine best number of clusters/groups using silhouette score

from sklearn.metrics import silhouette_score
K = range(3, 10)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    silhouette.append(silhouette_score(X_prep, kmeans.predict(X_prep)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette score showing the optimal k')

#in silhouette score, the higher score the better
#optimal k-value is 6
# Out:
# Text(0.5, 1.0, 'Silhouette score showing the optimal k')

# %% [markdown]
# ### We choose 6 clusters

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=6, random_state=1234)
kmeans.fit(X_prep)
# Out:
# KMeans(n_clusters=6, random_state=1234)

# %%
# Predicting / assigning the clusters:
clusters = kmeans.predict(X_prep)

# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()

# %%
clusters   #this is now an array of all the songs assigned a cluster

# %%
import pickle

#Saving the model
pickle.dump(kmeans, open('model.pkl', 'wb'))

# %%
#Plotting first column with 4th 

plt.figure(figsize=(5, 5))
plt.scatter(X_prep[:, 0], X_prep[:, 3], c=clusters,alpha=0.5) #visualizing column 0 and column 4
plt.show()

# %%
#Plotting first column with 2nd

plt.figure(figsize=(5, 5))
plt.scatter(X_prep[:, 0], X_prep[:, 1], c=clusters,alpha=0.5) #visualizing column 0 and column 4
plt.show()

# %%
spotify_cluster.head()
# Out:
#                              song          artist  \
# 0            Like a Rolling Stone       Bob Dylan
# 1         Smells Like Teen Spirit         Nirvana
# 2  A Day In The Life - Remastered     The Beatles
# 3          Good Vibrations (Mono)  The Beach Boys
# 4                  Johnny B Goode     Chuck Berry
#
#                                     uri  danceability  energy  loudness  \
# 0  spotify:track:3AhXZa8sUQht0UEdBJgpGc         0.482   0.721    -6.839
# 1  spotify:track:3oTlkzk1OtrhH8wBAduVEi         0.485   0.863    -9.027
# 2  spotify:track:3ZFBeIyP41HhnALjxWy1pR         0.364   0.457   -14.162
# 3  spotify:track:5Qt4Cc66g24QWwGP3YYV9y         0.398   0.413   -10.934
# 4  spotify:track:7MH2ZclofPlTrZOkPzZKhK         0.518   0.756   -10.851
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 0       0.0321      0.731000          0.000000    0.1890    0.557   95.263
# 1       0.0495      0.000012          0.016200    0.1380    0.767  116.835
# 2       0.0675      0.290000          0.000106    0.9220    0.175  163.219
# 3       0.0388      0.082200          0.000025    0.0891    0.331  133.574
# 4       0.0915      0.735000          0.000062    0.3170    0.968  166.429

# %%
spotify_cluster['cluster'] = clusters

# %%
spotify_cluster   #can see the final column is assigning each song to a cluster
# Out:
#                                 song                  artist  \
# 0               Like a Rolling Stone               Bob Dylan
# 1            Smells Like Teen Spirit                 Nirvana
# 2     A Day In The Life - Remastered             The Beatles
# 3             Good Vibrations (Mono)          The Beach Boys
# 4                     Johnny B Goode             Chuck Berry
# ...                              ...                     ...
# 9942                 Into The Valley                   Skids
# 9943              Tonight's Da Night                  Redman
# 9944                        Figure 8               FKA twigs
# 9945                   Like An Angel  The Mighty Lemon Drops
# 9946                    Come Dancing               The Kinks
#
#                                        uri  danceability  energy  loudness  \
# 0     spotify:track:3AhXZa8sUQht0UEdBJgpGc         0.482   0.721    -6.839
# 1     spotify:track:3oTlkzk1OtrhH8wBAduVEi         0.485   0.863    -9.027
# 2     spotify:track:3ZFBeIyP41HhnALjxWy1pR         0.364   0.457   -14.162
# 3     spotify:track:5Qt4Cc66g24QWwGP3YYV9y         0.398   0.413   -10.934
# 4     spotify:track:7MH2ZclofPlTrZOkPzZKhK         0.518   0.756   -10.851
# ...                                    ...           ...     ...       ...
# 9942  spotify:track:2QSD3K3b3BJ8DPhGhQfDPW         0.332   0.707   -12.698
# 9943  spotify:track:49XnDVsYOHgV4gFZeCojKj         0.464   0.749    -8.564
# 9944  spotify:track:5Y9IIH8Xmo1nuk0gfFjc4Q         0.694   0.710    -9.793
# 9945  spotify:track:0ya0JYEFoXNviB8RMeHDtW         0.332   0.800    -9.746
# 9946  spotify:track:32y1kRg6IF3f6jpkHxzFoK         0.499   0.763   -11.617
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.0321      0.731000          0.000000    0.1890    0.557   95.263
# 1          0.0495      0.000012          0.016200    0.1380    0.767  116.835
# 2          0.0675      0.290000          0.000106    0.9220    0.175  163.219
# 3          0.0388      0.082200          0.000025    0.0891    0.331  133.574
# 4          0.0915      0.735000          0.000062    0.3170    0.968  166.429
# ...           ...           ...               ...       ...      ...      ...
# 9942       0.0361      0.000012          0.006120    0.1100    0.652  144.815
# 9943       0.4800      0.224000          0.000046    0.3510    0.879  181.121
# 9944       0.3400      0.527000          0.001350    0.0697    0.415  119.964
# 9945       0.0326      0.000368          0.001600    0.0850    0.832  149.240
# 9946       0.0704      0.244000          0.000014    0.0828    0.895  152.677
#
#       cluster
# 0           3
# 1           3
# 2           0
# 3           1
# 4           3
# ...       ...
# 9942        1
# 9943        5
# 9944        5
# 9945        1
# 9946        3
#
# [9947 rows x 13 columns]

# %%
#Filter all cluster 0
spotify_cluster[spotify_cluster['cluster'] == 0]
# Out:
#                                              song                     artist  \
# 2                  A Day In The Life - Remastered                The Beatles
# 19                                   Paper Planes                     M.I.A.
# 30                                 When Doves Cry                     Prince
# 57                             Mr. Tambourine Man                  The Byrds
# 62    Unfinished Sympathy - 2006 Digital Remaster             Massive Attack
# ...                                           ...                        ...
# 9878                                Dear Prudence  Siouxsie and the Banshees
# 9894                     Primetime (feat. Miguel)              Janelle Monáe
# 9900                           A Question Of Time               Depeche Mode
# 9933                               Maybe Tomorrow              Stereophonics
# 9934                                    Dimension                 Wolfmother
#
#                                        uri  danceability  energy  loudness  \
# 2     spotify:track:3ZFBeIyP41HhnALjxWy1pR         0.364   0.457   -14.162
# 19    spotify:track:5QlGALr14YMN0xIDmIwleg         0.541   0.854    -6.196
# 30    spotify:track:51H2y6YrNNXcy3dfc3qSbA         0.729   0.989    -4.613
# 57    spotify:track:2HCaIYjkvWSZzaSKUoOh3d         0.456   0.470    -9.564
# 62    spotify:track:7cFfFVVubc4K5qB0jGyguY         0.592   0.891    -5.637
# ...                                    ...           ...     ...       ...
# 9878  spotify:track:0NrA3AznsL2lZfuZxOiIhu         0.423   0.896    -4.392
# 9894  spotify:track:5dzV75f9qVXVvdXLTqIG4L         0.667   0.465    -8.096
# 9900  spotify:track:3MZ0p7nALhbkLJfjP80fU8         0.581   0.781   -11.803
# 9933  spotify:track:4M7XzMb9rNL4rncIXR5pD6         0.495   0.653    -6.769
# 9934  spotify:track:7vonqPUq6XM98ByB1LV264         0.484   0.749    -4.170
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 2          0.0675       0.29000          0.000106     0.922    0.175  163.219
# 19         0.1550       0.02540          0.000125     0.651    0.454   86.044
# 30         0.0490       0.01020          0.000044     0.443    0.840  126.470
# 57         0.0294       0.51300          0.000038     0.444    0.639  120.336
# 62         0.0316       0.01450          0.141000     0.394    0.717  114.348
# ...           ...           ...               ...       ...      ...      ...
# 9878       0.0467       0.01270          0.001190     0.681    0.428  101.512
# 9894       0.0339       0.04260          0.006490     0.465    0.340  123.883
# 9900       0.0293       0.00742          0.040500     0.373    0.729  136.202
# 9933       0.0361       0.21700          0.000458     0.334    0.571   80.897
# 9934       0.0327       0.01860          0.009900     0.436    0.613  142.165
#
#       cluster
# 2           0
# 19          0
# 30          0
# 57          0
# 62          0
# ...       ...
# 9878        0
# 9894        0
# 9900        0
# 9933        0
# 9934        0
#
# [695 rows x 13 columns]

# %%
spotify_cluster[spotify_cluster['cluster'] == 5]
# Out:
#                                              song  \
# 21                         Sympathy For The Devil
# 25    The Message (feat. Melle Mel & Duke Bootee)
# 36                    Crazy In Love (feat. Jay-Z)
# 50                                Get Ur Freak On
# 64                                Fight The Power
# ...                                           ...
# 9927                                       Biking
# 9928                                        Sugar
# 9930                                   Successful
# 9943                           Tonight's Da Night
# 9944                                     Figure 8
#
#                                     artist  \
# 21                      The Rolling Stones
# 25    Grandmaster Flash & The Furious Five
# 36                                 Beyoncé
# 50                           Missy Elliott
# 64                            Public Enemy
# ...                                    ...
# 9927                           Frank Ocean
# 9928                      System Of A Down
# 9930                                 Drake
# 9943                                Redman
# 9944                             FKA twigs
#
#                                        uri  danceability  energy  loudness  \
# 21    spotify:track:4sFbojhVXQv7dBC9PVCcRn         0.566   0.673   -10.814
# 25    spotify:track:5DuTNKFEjJIySAyJH1yNDU         0.947   0.607   -10.580
# 36    spotify:track:5IVuqXILoxVWvWEPm82Jxr         0.646   0.770    -6.596
# 50    spotify:track:13KEdaWIc7T6ozEmnJjHy1         0.780   0.787    -6.653
# 64    spotify:track:26zWdOUpB6P9E9OtQQc0qp         0.798   0.586   -13.001
# ...                                    ...           ...     ...       ...
# 9927  spotify:track:2q0VexHJirnUPnEOhr2DxK         0.673   0.463    -7.247
# 9928  spotify:track:31RTFPrB7wmYBhlkM2ILXG         0.451   0.889    -2.693
# 9930  spotify:track:1WvBza6fVzy7OK2JbWKRyn         0.735   0.416    -7.939
# 9943  spotify:track:49XnDVsYOHgV4gFZeCojKj         0.464   0.749    -8.564
# 9944  spotify:track:5Y9IIH8Xmo1nuk0gfFjc4Q         0.694   0.710    -9.793
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 21          0.306       0.56500          0.000001    0.0438    0.583  114.385
# 25          0.202       0.02490          0.000005    0.0861    0.732  100.619
# 36          0.226       0.00249          0.000000    0.0715    0.681   99.165
# 50          0.209       0.53300          0.134000    0.1220    0.668  177.835
# 64          0.255       0.00556          0.000002    0.4730    0.381  105.979
# ...           ...           ...               ...       ...      ...      ...
# 9927        0.191       0.68100          0.000005    0.0907    0.268  147.981
# 9928        0.261       0.00167          0.002150    0.2580    0.586  131.073
# 9930        0.387       0.46400          0.000000    0.1140    0.229  159.109
# 9943        0.480       0.22400          0.000046    0.3510    0.879  181.121
# 9944        0.340       0.52700          0.001350    0.0697    0.415  119.964
#
#       cluster
# 21          5
# 25          5
# 36          5
# 50          5
# 64          5
# ...       ...
# 9927        5
# 9928        5
# 9930        5
# 9943        5
# 9944        5
#
# [646 rows x 13 columns]

# %%
spotify_cluster.to_csv('clustered_df.csv')
